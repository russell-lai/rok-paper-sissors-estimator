# %% [markdown]
# This file is only for local testing. It will not be pushed.

# %%
from rok_estimator import *
from lattice_lib import *
from lattice_lib.util import *

# %%
ring_params = {
    "f": 60,
    "log_beta_sis_2": 36,
    "log_q": 64,
}

rel_params = {
    "wdim": 2**16 * 41,
    "rep": 25,
    "log_beta_wit_inf": 0,
}

ops_params = {
    "ell": 3,
    "d": 2,
}

opener = [
    ("norm", {}), 
    ("batch", {}), 
    ("split", {"d": ops_params["d"]}), 
    ("fold", {})
]
loop = [
    ("bdecomp", {"ell": ops_params["ell"]}), 
    ("norm", {}), 
    ("batch", {}), 
    ("split", {"d": ops_params["d"]}), 
    ("fold", {})
]
ops = opener + 10 * loop + [("finish", {})]

sim = Simulation(ring_params, rel_params)
sim.execute(ops)
sim.extract()
sim.show(brief=False)
# Out:
# Ring parameters:
#     conductor f: 60, degree phi: 16, modulus q: 2^64, beta_sis_2: 2^36
#     SIS module rank n_sis: 50, target SIS security: 128, resulting SIS security: 129
#     residue degree: 2, target Schwartz-Zippel security: 80, resulting Schwartz-Zippel security: 128
#     |R_q| = 128.0 B, |R_q^(n_sis)| = 6.250 KB
#
# Subtractive set parameters:
#     cardinality: 12
#     forward ell_2 expansion factor gamma_2: 2^0
#     inverse ell_2 expansion factor theta_2: 2^4
#     forward ell_inf expansion factor gamma_inf: 2^2
#     inverse ell_inf expansion factor theta_inf: 2^5
#
# Relation:
#     H * F * W = Y
# Statement:
#     H: n_compress x (n_commit + n_rel)
#     F: (n_commit + n_rel) x wdim
#     Y: n_compress x rep
# Witness:
#     W: wdim x rep
#     ||sigma(W)||_2 <= 2^log_beta_wit_2 measured in max column canonical ell_2-norm
#     ||psi(W)||_inf <= 2^log_beta_wit_inf
# Parameters:
#     n_compress = 50, n_commit = 50, n_rel = 0
#     wdim = 2686976, rep = 25
#     log_2-norm (real | extr) = (16 |16 ), log_inf-norm (real | extr) = (0|16)
#     wit size = 128.1 MB
#
# Execution Trace:
# init    : wdim =  2686976, rep =  25, log_2-norm (real | extr) = ( 16 | 16 ), log_inf-norm (real | extr) = (  0 | 16 ), wit size = 128.1 MB
# norm    : wdim =  2686976, rep =  41, log_2-norm (real | extr) = ( 16 | 31 ), log_inf-norm (real | extr) = (  0 | 29 ), wit size = 210.1 MB
# batch   : wdim =  2686976, rep =  41, log_2-norm (real | extr) = ( 16 | 31 ), log_inf-norm (real | extr) = (  0 | 29 ), wit size = 210.1 MB
# split   : wdim =  1343488, rep =  82, log_2-norm (real | extr) = ( 16 | 31 ), log_inf-norm (real | extr) = (  0 | 29 ), wit size = 210.1 MB
# fold    : wdim =  1343488, rep =  25, log_2-norm (real | extr) = ( 23 | 24 ), log_inf-norm (real | extr) = (  9 | 24 ), wit size = 640.6 MB
# bdecomp : wdim =  1343488, rep =  75, log_2-norm (real | extr) = ( 17 | 17 ), log_inf-norm (real | extr) = (  2 | 17 ), wit size = 576.6 MB
# norm    : wdim =  1343488, rep =  84, log_2-norm (real | extr) = ( 17 | 34 ), log_inf-norm (real | extr) = (  2 | 31 ), wit size = 645.8 MB
# batch   : wdim =  1343488, rep =  84, log_2-norm (real | extr) = ( 17 | 34 ), log_inf-norm (real | extr) = (  2 | 31 ), wit size = 645.8 MB
# split   : wdim =   671744, rep = 168, log_2-norm (real | extr) = ( 17 | 34 ), log_inf-norm (real | extr) = (  2 | 31 ), wit size = 645.8 MB
# fold    : wdim =   671744, rep =  26, log_2-norm (real | extr) = ( 25 | 26 ), log_inf-norm (real | extr) = ( 12 | 26 ), wit size = 433.1 MB
# bdecomp : wdim =   671744, rep =  78, log_2-norm (real | extr) = ( 18 | 18 ), log_inf-norm (real | extr) = (  4 | 18 ), wit size = 499.7 MB
# norm    : wdim =   671744, rep =  85, log_2-norm (real | extr) = ( 18 | 35 ), log_inf-norm (real | extr) = (  4 | 32 ), wit size = 544.5 MB
# batch   : wdim =   671744, rep =  85, log_2-norm (real | extr) = ( 18 | 35 ), log_inf-norm (real | extr) = (  4 | 32 ), wit size = 544.5 MB
# split   : wdim =   335872, rep = 170, log_2-norm (real | extr) = ( 18 | 35 ), log_inf-norm (real | extr) = (  4 | 32 ), wit size = 544.5 MB
# fold    : wdim =   335872, rep =  26, log_2-norm (real | extr) = ( 25 | 27 ), log_inf-norm (real | extr) = ( 13 | 27 ), wit size = 233.2 MB
# bdecomp : wdim =   335872, rep =  78, log_2-norm (real | extr) = ( 18 | 18 ), log_inf-norm (real | extr) = (  4 | 18 ), wit size = 249.8 MB
# norm    : wdim =   335872, rep =  85, log_2-norm (real | extr) = ( 18 | 35 ), log_inf-norm (real | extr) = (  4 | 32 ), wit size = 272.3 MB
# batch   : wdim =   335872, rep =  85, log_2-norm (real | extr) = ( 18 | 35 ), log_inf-norm (real | extr) = (  4 | 32 ), wit size = 272.3 MB
# split   : wdim =   167936, rep = 170, log_2-norm (real | extr) = ( 18 | 35 ), log_inf-norm (real | extr) = (  4 | 32 ), wit size = 272.3 MB
# fold    : wdim =   167936, rep =  26, log_2-norm (real | extr) = ( 25 | 27 ), log_inf-norm (real | extr) = ( 13 | 27 ), wit size = 116.6 MB
# bdecomp : wdim =   167936, rep =  78, log_2-norm (real | extr) = ( 17 | 17 ), log_inf-norm (real | extr) = (  4 | 17 ), wit size = 124.9 MB
# norm    : wdim =   167936, rep =  85, log_2-norm (real | extr) = ( 17 | 35 ), log_inf-norm (real | extr) = (  4 | 31 ), wit size = 136.1 MB
# batch   : wdim =   167936, rep =  85, log_2-norm (real | extr) = ( 17 | 35 ), log_inf-norm (real | extr) = (  4 | 31 ), wit size = 136.1 MB
# split   : wdim =    83968, rep = 170, log_2-norm (real | extr) = ( 17 | 35 ), log_inf-norm (real | extr) = (  4 | 31 ), wit size = 136.1 MB
# fold    : wdim =    83968, rep =  26, log_2-norm (real | extr) = ( 25 | 26 ), log_inf-norm (real | extr) = ( 14 | 26 ), wit size = 62.46 MB
# bdecomp : wdim =    83968, rep =  78, log_2-norm (real | extr) = ( 17 | 17 ), log_inf-norm (real | extr) = (  4 | 17 ), wit size = 62.46 MB
# norm    : wdim =    83968, rep =  84, log_2-norm (real | extr) = ( 17 | 34 ), log_inf-norm (real | extr) = (  4 | 31 ), wit size = 67.27 MB
# batch   : wdim =    83968, rep =  84, log_2-norm (real | extr) = ( 17 | 34 ), log_inf-norm (real | extr) = (  4 | 31 ), wit size = 67.27 MB
# split   : wdim =    41984, rep = 168, log_2-norm (real | extr) = ( 17 | 34 ), log_inf-norm (real | extr) = (  4 | 31 ), wit size = 67.27 MB
# fold    : wdim =    41984, rep =  26, log_2-norm (real | extr) = ( 24 | 26 ), log_inf-norm (real | extr) = ( 14 | 26 ), wit size = 31.23 MB
# bdecomp : wdim =    41984, rep =  78, log_2-norm (real | extr) = ( 16 | 16 ), log_inf-norm (real | extr) = (  4 | 16 ), wit size = 31.23 MB
# norm    : wdim =    41984, rep =  84, log_2-norm (real | extr) = ( 16 | 33 ), log_inf-norm (real | extr) = (  4 | 30 ), wit size = 33.63 MB
# batch   : wdim =    41984, rep =  84, log_2-norm (real | extr) = ( 16 | 33 ), log_inf-norm (real | extr) = (  4 | 30 ), wit size = 33.63 MB
# split   : wdim =    20992, rep = 168, log_2-norm (real | extr) = ( 16 | 33 ), log_inf-norm (real | extr) = (  4 | 30 ), wit size = 33.63 MB
# fold    : wdim =    20992, rep =  26, log_2-norm (real | extr) = ( 24 | 25 ), log_inf-norm (real | extr) = ( 14 | 25 ), wit size = 15.62 MB
# bdecomp : wdim =    20992, rep =  78, log_2-norm (real | extr) = ( 16 | 16 ), log_inf-norm (real | extr) = (  4 | 16 ), wit size = 15.62 MB
# norm    : wdim =    20992, rep =  84, log_2-norm (real | extr) = ( 16 | 33 ), log_inf-norm (real | extr) = (  4 | 30 ), wit size = 16.82 MB
# batch   : wdim =    20992, rep =  84, log_2-norm (real | extr) = ( 16 | 33 ), log_inf-norm (real | extr) = (  4 | 30 ), wit size = 16.82 MB
# split   : wdim =    10496, rep = 168, log_2-norm (real | extr) = ( 16 | 33 ), log_inf-norm (real | extr) = (  4 | 30 ), wit size = 16.82 MB
# fold    : wdim =    10496, rep =  26, log_2-norm (real | extr) = ( 23 | 25 ), log_inf-norm (real | extr) = ( 14 | 25 ), wit size = 7.808 MB
# bdecomp : wdim =    10496, rep =  78, log_2-norm (real | extr) = ( 15 | 15 ), log_inf-norm (real | extr) = (  4 | 15 ), wit size = 7.808 MB
# norm    : wdim =    10496, rep =  84, log_2-norm (real | extr) = ( 15 | 32 ), log_inf-norm (real | extr) = (  4 | 29 ), wit size = 8.408 MB
# batch   : wdim =    10496, rep =  84, log_2-norm (real | extr) = ( 15 | 32 ), log_inf-norm (real | extr) = (  4 | 29 ), wit size = 8.408 MB
# split   : wdim =     5248, rep = 168, log_2-norm (real | extr) = ( 15 | 32 ), log_inf-norm (real | extr) = (  4 | 29 ), wit size = 8.408 MB
# fold    : wdim =     5248, rep =  26, log_2-norm (real | extr) = ( 23 | 24 ), log_inf-norm (real | extr) = ( 14 | 24 ), wit size = 3.904 MB
# bdecomp : wdim =     5248, rep =  78, log_2-norm (real | extr) = ( 15 | 15 ), log_inf-norm (real | extr) = (  4 | 15 ), wit size = 3.904 MB
# norm    : wdim =     5248, rep =  83, log_2-norm (real | extr) = ( 15 | 32 ), log_inf-norm (real | extr) = (  4 | 29 ), wit size = 4.154 MB
# batch   : wdim =     5248, rep =  83, log_2-norm (real | extr) = ( 15 | 32 ), log_inf-norm (real | extr) = (  4 | 29 ), wit size = 4.154 MB
# split   : wdim =     2624, rep = 166, log_2-norm (real | extr) = ( 15 | 32 ), log_inf-norm (real | extr) = (  4 | 29 ), wit size = 4.154 MB
# fold    : wdim =     2624, rep =  26, log_2-norm (real | extr) = ( 22 | 24 ), log_inf-norm (real | extr) = ( 14 | 24 ), wit size = 1.952 MB
# bdecomp : wdim =     2624, rep =  78, log_2-norm (real | extr) = ( 14 | 14 ), log_inf-norm (real | extr) = (  4 | 14 ), wit size = 1.952 MB
# norm    : wdim =     2624, rep =  83, log_2-norm (real | extr) = ( 14 | 30 ), log_inf-norm (real | extr) = (  4 | 19 ), wit size = 2.077 MB
# batch   : wdim =     2624, rep =  83, log_2-norm (real | extr) = ( 14 | 30 ), log_inf-norm (real | extr) = (  4 | 19 ), wit size = 2.077 MB
# split   : wdim =     1312, rep = 166, log_2-norm (real | extr) = ( 14 | 30 ), log_inf-norm (real | extr) = (  4 | 19 ), wit size = 2.077 MB
# fold    : wdim =     1312, rep =  26, log_2-norm (real | extr) = ( 22 | 22 ), log_inf-norm (real | extr) = ( 14 | 14 ), wit size = 999.4 KB
# finish  : True
#
# Costs:
# norm    : communication = 115.4 KB, soundness error = 2^-106
# batch   : communication = 0.0000 B, soundness error = 2^-122
# split   : communication = 271.6 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-84
# bdecomp : communication = 318.8 KB, soundness error = 2^-Infinity
# norm    : communication = 91.12 KB, soundness error = 2^-107
# batch   : communication = 0.0000 B, soundness error = 2^-120
# split   : communication = 556.5 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 331.5 KB, soundness error = 2^-Infinity
# norm    : communication = 80.88 KB, soundness error = 2^-108
# batch   : communication = 0.0000 B, soundness error = 2^-119
# split   : communication = 563.1 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 331.5 KB, soundness error = 2^-Infinity
# norm    : communication = 83.50 KB, soundness error = 2^-109
# batch   : communication = 0.0000 B, soundness error = 2^-119
# split   : communication = 563.1 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 331.5 KB, soundness error = 2^-Infinity
# norm    : communication = 86.12 KB, soundness error = 2^-110
# batch   : communication = 0.0000 B, soundness error = 2^-118
# split   : communication = 563.1 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 331.5 KB, soundness error = 2^-Infinity
# norm    : communication = 80.25 KB, soundness error = 2^-111
# batch   : communication = 0.0000 B, soundness error = 2^-118
# split   : communication = 556.5 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 331.5 KB, soundness error = 2^-Infinity
# norm    : communication = 82.50 KB, soundness error = 2^-112
# batch   : communication = 0.0000 B, soundness error = 2^-118
# split   : communication = 556.5 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 331.5 KB, soundness error = 2^-Infinity
# norm    : communication = 84.75 KB, soundness error = 2^-113
# batch   : communication = 0.0000 B, soundness error = 2^-118
# split   : communication = 556.5 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 331.5 KB, soundness error = 2^-Infinity
# norm    : communication = 87.00 KB, soundness error = 2^-114
# batch   : communication = 0.0000 B, soundness error = 2^-117
# split   : communication = 556.5 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 331.5 KB, soundness error = 2^-Infinity
# norm    : communication = 79.25 KB, soundness error = 2^-115
# batch   : communication = 0.0000 B, soundness error = 2^-117
# split   : communication = 549.9 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 331.5 KB, soundness error = 2^-Infinity
# norm    : communication = 81.12 KB, soundness error = 2^-116
# batch   : communication = 0.0000 B, soundness error = 2^-117
# split   : communication = 549.9 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# finish  : communication = 999.4 KB, soundness error = 2^-Infinity
#
# Total Cost: communication = 10.84 MB, soundness error = 2^-82
# Maximum log ell_2-norm (real | extr) = ( 25 | 35 ), log SIS norm bound = 36

# %%
ring_params = {
    "f": 60,
    "log_beta_sis_2": 37,
    "log_q": 64,
}

rel_params = {
    "wdim": 2**16 * 41,
    "rep": 25,
    "log_beta_wit_inf": 10,
}

ops_params = {
    "ell": 3,
    "d": 2,
}

loop = [
    ("bdecomp", {"ell": ops_params["ell"]}), 
    ("norm", {}), 
    ("batch", {}), 
    ("split", {"d": ops_params["d"]}), 
    ("fold", {})
]
ops = 10 * loop + [("finish", {})]

sim = Simulation(ring_params, rel_params)
sim.execute(ops)
sim.extract()
sim.show(brief=False)
# Out:
# Ring parameters:
#     conductor f: 60, degree phi: 16, modulus q: 2^64, beta_sis_2: 2^37
#     SIS module rank n_sis: 53, target SIS security: 128, resulting SIS security: 129
#     residue degree: 2, target Schwartz-Zippel security: 80, resulting Schwartz-Zippel security: 128
#     |R_q| = 128.0 B, |R_q^(n_sis)| = 6.625 KB
#
# Subtractive set parameters:
#     cardinality: 12
#     forward ell_2 expansion factor gamma_2: 2^0
#     inverse ell_2 expansion factor theta_2: 2^4
#     forward ell_inf expansion factor gamma_inf: 2^2
#     inverse ell_inf expansion factor theta_inf: 2^5
#
# Relation:
#     H * F * W = Y
# Statement:
#     H: n_compress x (n_commit + n_rel)
#     F: (n_commit + n_rel) x wdim
#     Y: n_compress x rep
# Witness:
#     W: wdim x rep
#     ||sigma(W)||_2 <= 2^log_beta_wit_2 measured in max column canonical ell_2-norm
#     ||psi(W)||_inf <= 2^log_beta_wit_inf
# Parameters:
#     n_compress = 53, n_commit = 53, n_rel = 0
#     wdim = 2686976, rep = 25
#     log_2-norm (real | extr) = (26 |26 ), log_inf-norm (real | extr) = (10|26)
#     wit size = 1409. MB
#
# Execution Trace:
# init    : wdim =  2686976, rep =  25, log_2-norm (real | extr) = ( 26 | 26 ), log_inf-norm (real | extr) = ( 10 | 26 ), wit size = 1409. MB
# bdecomp : wdim =  2686976, rep =  75, log_2-norm (real | extr) = ( 18 | 18 ), log_inf-norm (real | extr) = (  3 | 18 ), wit size = 1538. MB
# norm    : wdim =  2686976, rep =  84, log_2-norm (real | extr) = ( 18 | 35 ), log_inf-norm (real | extr) = (  3 | 32 ), wit size = 1722. MB
# batch   : wdim =  2686976, rep =  84, log_2-norm (real | extr) = ( 18 | 35 ), log_inf-norm (real | extr) = (  3 | 32 ), wit size = 1722. MB
# split   : wdim =  1343488, rep = 168, log_2-norm (real | extr) = ( 18 | 35 ), log_inf-norm (real | extr) = (  3 | 32 ), wit size = 1722. MB
# fold    : wdim =  1343488, rep =  26, log_2-norm (real | extr) = ( 26 | 27 ), log_inf-norm (real | extr) = ( 12 | 27 ), wit size = 866.1 MB
# bdecomp : wdim =  1343488, rep =  78, log_2-norm (real | extr) = ( 18 | 18 ), log_inf-norm (real | extr) = (  4 | 18 ), wit size = 999.4 MB
# norm    : wdim =  1343488, rep =  86, log_2-norm (real | extr) = ( 18 | 36 ), log_inf-norm (real | extr) = (  4 | 33 ), wit size = 1102. MB
# batch   : wdim =  1343488, rep =  86, log_2-norm (real | extr) = ( 18 | 36 ), log_inf-norm (real | extr) = (  4 | 33 ), wit size = 1102. MB
# split   : wdim =   671744, rep = 172, log_2-norm (real | extr) = ( 18 | 36 ), log_inf-norm (real | extr) = (  4 | 33 ), wit size = 1102. MB
# fold    : wdim =   671744, rep =  26, log_2-norm (real | extr) = ( 26 | 27 ), log_inf-norm (real | extr) = ( 13 | 27 ), wit size = 466.4 MB
# bdecomp : wdim =   671744, rep =  78, log_2-norm (real | extr) = ( 18 | 18 ), log_inf-norm (real | extr) = (  4 | 18 ), wit size = 499.7 MB
# norm    : wdim =   671744, rep =  85, log_2-norm (real | extr) = ( 18 | 35 ), log_inf-norm (real | extr) = (  4 | 32 ), wit size = 544.5 MB
# batch   : wdim =   671744, rep =  85, log_2-norm (real | extr) = ( 18 | 35 ), log_inf-norm (real | extr) = (  4 | 32 ), wit size = 544.5 MB
# split   : wdim =   335872, rep = 170, log_2-norm (real | extr) = ( 18 | 35 ), log_inf-norm (real | extr) = (  4 | 32 ), wit size = 544.5 MB
# fold    : wdim =   335872, rep =  26, log_2-norm (real | extr) = ( 26 | 27 ), log_inf-norm (real | extr) = ( 13 | 27 ), wit size = 233.2 MB
# bdecomp : wdim =   335872, rep =  78, log_2-norm (real | extr) = ( 18 | 18 ), log_inf-norm (real | extr) = (  4 | 18 ), wit size = 249.8 MB
# norm    : wdim =   335872, rep =  85, log_2-norm (real | extr) = ( 18 | 35 ), log_inf-norm (real | extr) = (  4 | 32 ), wit size = 272.3 MB
# batch   : wdim =   335872, rep =  85, log_2-norm (real | extr) = ( 18 | 35 ), log_inf-norm (real | extr) = (  4 | 32 ), wit size = 272.3 MB
# split   : wdim =   167936, rep = 170, log_2-norm (real | extr) = ( 18 | 35 ), log_inf-norm (real | extr) = (  4 | 32 ), wit size = 272.3 MB
# fold    : wdim =   167936, rep =  26, log_2-norm (real | extr) = ( 25 | 27 ), log_inf-norm (real | extr) = ( 14 | 27 ), wit size = 124.9 MB
# bdecomp : wdim =   167936, rep =  78, log_2-norm (real | extr) = ( 17 | 17 ), log_inf-norm (real | extr) = (  4 | 17 ), wit size = 124.9 MB
# norm    : wdim =   167936, rep =  85, log_2-norm (real | extr) = ( 17 | 35 ), log_inf-norm (real | extr) = (  4 | 31 ), wit size = 136.1 MB
# batch   : wdim =   167936, rep =  85, log_2-norm (real | extr) = ( 17 | 35 ), log_inf-norm (real | extr) = (  4 | 31 ), wit size = 136.1 MB
# split   : wdim =    83968, rep = 170, log_2-norm (real | extr) = ( 17 | 35 ), log_inf-norm (real | extr) = (  4 | 31 ), wit size = 136.1 MB
# fold    : wdim =    83968, rep =  26, log_2-norm (real | extr) = ( 25 | 26 ), log_inf-norm (real | extr) = ( 14 | 26 ), wit size = 62.46 MB
# bdecomp : wdim =    83968, rep =  78, log_2-norm (real | extr) = ( 17 | 17 ), log_inf-norm (real | extr) = (  4 | 17 ), wit size = 62.46 MB
# norm    : wdim =    83968, rep =  84, log_2-norm (real | extr) = ( 17 | 34 ), log_inf-norm (real | extr) = (  4 | 31 ), wit size = 67.27 MB
# batch   : wdim =    83968, rep =  84, log_2-norm (real | extr) = ( 17 | 34 ), log_inf-norm (real | extr) = (  4 | 31 ), wit size = 67.27 MB
# split   : wdim =    41984, rep = 168, log_2-norm (real | extr) = ( 17 | 34 ), log_inf-norm (real | extr) = (  4 | 31 ), wit size = 67.27 MB
# fold    : wdim =    41984, rep =  26, log_2-norm (real | extr) = ( 24 | 26 ), log_inf-norm (real | extr) = ( 14 | 26 ), wit size = 31.23 MB
# bdecomp : wdim =    41984, rep =  78, log_2-norm (real | extr) = ( 16 | 16 ), log_inf-norm (real | extr) = (  4 | 16 ), wit size = 31.23 MB
# norm    : wdim =    41984, rep =  84, log_2-norm (real | extr) = ( 16 | 33 ), log_inf-norm (real | extr) = (  4 | 30 ), wit size = 33.63 MB
# batch   : wdim =    41984, rep =  84, log_2-norm (real | extr) = ( 16 | 33 ), log_inf-norm (real | extr) = (  4 | 30 ), wit size = 33.63 MB
# split   : wdim =    20992, rep = 168, log_2-norm (real | extr) = ( 16 | 33 ), log_inf-norm (real | extr) = (  4 | 30 ), wit size = 33.63 MB
# fold    : wdim =    20992, rep =  26, log_2-norm (real | extr) = ( 24 | 25 ), log_inf-norm (real | extr) = ( 14 | 25 ), wit size = 15.62 MB
# bdecomp : wdim =    20992, rep =  78, log_2-norm (real | extr) = ( 16 | 16 ), log_inf-norm (real | extr) = (  4 | 16 ), wit size = 15.62 MB
# norm    : wdim =    20992, rep =  84, log_2-norm (real | extr) = ( 16 | 33 ), log_inf-norm (real | extr) = (  4 | 30 ), wit size = 16.82 MB
# batch   : wdim =    20992, rep =  84, log_2-norm (real | extr) = ( 16 | 33 ), log_inf-norm (real | extr) = (  4 | 30 ), wit size = 16.82 MB
# split   : wdim =    10496, rep = 168, log_2-norm (real | extr) = ( 16 | 33 ), log_inf-norm (real | extr) = (  4 | 30 ), wit size = 16.82 MB
# fold    : wdim =    10496, rep =  26, log_2-norm (real | extr) = ( 23 | 25 ), log_inf-norm (real | extr) = ( 14 | 25 ), wit size = 7.808 MB
# bdecomp : wdim =    10496, rep =  78, log_2-norm (real | extr) = ( 15 | 15 ), log_inf-norm (real | extr) = (  4 | 15 ), wit size = 7.808 MB
# norm    : wdim =    10496, rep =  84, log_2-norm (real | extr) = ( 15 | 32 ), log_inf-norm (real | extr) = (  4 | 29 ), wit size = 8.408 MB
# batch   : wdim =    10496, rep =  84, log_2-norm (real | extr) = ( 15 | 32 ), log_inf-norm (real | extr) = (  4 | 29 ), wit size = 8.408 MB
# split   : wdim =     5248, rep = 168, log_2-norm (real | extr) = ( 15 | 32 ), log_inf-norm (real | extr) = (  4 | 29 ), wit size = 8.408 MB
# fold    : wdim =     5248, rep =  26, log_2-norm (real | extr) = ( 23 | 24 ), log_inf-norm (real | extr) = ( 14 | 24 ), wit size = 3.904 MB
# bdecomp : wdim =     5248, rep =  78, log_2-norm (real | extr) = ( 15 | 15 ), log_inf-norm (real | extr) = (  4 | 15 ), wit size = 3.904 MB
# norm    : wdim =     5248, rep =  83, log_2-norm (real | extr) = ( 15 | 30 ), log_inf-norm (real | extr) = (  4 | 19 ), wit size = 4.154 MB
# batch   : wdim =     5248, rep =  83, log_2-norm (real | extr) = ( 15 | 30 ), log_inf-norm (real | extr) = (  4 | 19 ), wit size = 4.154 MB
# split   : wdim =     2624, rep = 166, log_2-norm (real | extr) = ( 15 | 30 ), log_inf-norm (real | extr) = (  4 | 19 ), wit size = 4.154 MB
# fold    : wdim =     2624, rep =  26, log_2-norm (real | extr) = ( 22 | 22 ), log_inf-norm (real | extr) = ( 14 | 14 ), wit size = 1.952 MB
# finish  : True
#
# Costs:
# bdecomp : communication = 331.2 KB, soundness error = 2^-Infinity
# norm    : communication = 91.12 KB, soundness error = 2^-106
# batch   : communication = 0.0000 B, soundness error = 2^-121
# split   : communication = 588.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 351.0 KB, soundness error = 2^-Infinity
# norm    : communication = 88.25 KB, soundness error = 2^-107
# batch   : communication = 0.0000 B, soundness error = 2^-119
# split   : communication = 602.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 351.0 KB, soundness error = 2^-Infinity
# norm    : communication = 83.50 KB, soundness error = 2^-108
# batch   : communication = 0.0000 B, soundness error = 2^-119
# split   : communication = 595.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 351.0 KB, soundness error = 2^-Infinity
# norm    : communication = 86.12 KB, soundness error = 2^-109
# batch   : communication = 0.0000 B, soundness error = 2^-119
# split   : communication = 595.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 351.0 KB, soundness error = 2^-Infinity
# norm    : communication = 88.75 KB, soundness error = 2^-110
# batch   : communication = 0.0000 B, soundness error = 2^-118
# split   : communication = 595.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 351.0 KB, soundness error = 2^-Infinity
# norm    : communication = 82.50 KB, soundness error = 2^-111
# batch   : communication = 0.0000 B, soundness error = 2^-118
# split   : communication = 588.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 351.0 KB, soundness error = 2^-Infinity
# norm    : communication = 84.75 KB, soundness error = 2^-112
# batch   : communication = 0.0000 B, soundness error = 2^-118
# split   : communication = 588.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 351.0 KB, soundness error = 2^-Infinity
# norm    : communication = 87.00 KB, soundness error = 2^-113
# batch   : communication = 0.0000 B, soundness error = 2^-118
# split   : communication = 588.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 351.0 KB, soundness error = 2^-Infinity
# norm    : communication = 89.25 KB, soundness error = 2^-114
# batch   : communication = 0.0000 B, soundness error = 2^-117
# split   : communication = 588.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 351.0 KB, soundness error = 2^-Infinity
# norm    : communication = 81.12 KB, soundness error = 2^-115
# batch   : communication = 0.0000 B, soundness error = 2^-117
# split   : communication = 581.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# finish  : communication = 1.952 MB, soundness error = 2^-Infinity
#
# Total Cost: communication = 11.97 MB, soundness error = 2^-83
# Maximum log ell_2-norm (real | extr) = ( 26 | 36 ), log SIS norm bound = 37

# %%
ring_params = {
    "f": 60,
    "log_beta_sis_2": 37,
    "log_q": 64,
}

rel_params = {
    "wdim": 2**18 * 41,
    "rep": 25,
    "log_beta_wit_inf": 10,
}

ops_params = {
    "ell": 4,
    "d": 2,
}

loop = [
    ("bdecomp", {"ell": ops_params["ell"]}), 
    ("norm", {}), 
    ("batch", {}), 
    ("split", {"d": ops_params["d"]}), 
    ("fold", {})
]
ops = 12 * loop + [("finish", {})]

sim = Simulation(ring_params, rel_params)
sim.execute(ops)
sim.extract()
sim.show(brief=False)
# Out:
# Ring parameters:
#     conductor f: 60, degree phi: 16, modulus q: 2^64, beta_sis_2: 2^37
#     SIS module rank n_sis: 53, target SIS security: 128, resulting SIS security: 129
#     residue degree: 2, target Schwartz-Zippel security: 80, resulting Schwartz-Zippel security: 128
#     |R_q| = 128.0 B, |R_q^(n_sis)| = 6.625 KB
#
# Subtractive set parameters:
#     cardinality: 12
#     forward ell_2 expansion factor gamma_2: 2^0
#     inverse ell_2 expansion factor theta_2: 2^4
#     forward ell_inf expansion factor gamma_inf: 2^2
#     inverse ell_inf expansion factor theta_inf: 2^5
#
# Relation:
#     H * F * W = Y
# Statement:
#     H: n_compress x (n_commit + n_rel)
#     F: (n_commit + n_rel) x wdim
#     Y: n_compress x rep
# Witness:
#     W: wdim x rep
#     ||sigma(W)||_2 <= 2^log_beta_wit_2 measured in max column canonical ell_2-norm
#     ||psi(W)||_inf <= 2^log_beta_wit_inf
# Parameters:
#     n_compress = 53, n_commit = 53, n_rel = 0
#     wdim = 10747904, rep = 25
#     log_2-norm (real | extr) = (27 |27 ), log_inf-norm (real | extr) = (10|27)
#     wit size = 5638. MB
#
# Execution Trace:
# init    : wdim = 10747904, rep =  25, log_2-norm (real | extr) = ( 27 | 27 ), log_inf-norm (real | extr) = ( 10 | 27 ), wit size = 5638. MB
# bdecomp : wdim = 10747904, rep = 100, log_2-norm (real | extr) = ( 18 | 18 ), log_inf-norm (real | extr) = (  2 | 18 ), wit size = 6150. MB
# norm    : wdim = 10747904, rep = 111, log_2-norm (real | extr) = ( 18 | 36 ), log_inf-norm (real | extr) = (  2 | 33 ), wit size = 6826. MB
# batch   : wdim = 10747904, rep = 111, log_2-norm (real | extr) = ( 18 | 36 ), log_inf-norm (real | extr) = (  2 | 33 ), wit size = 6826. MB
# split   : wdim =  5373952, rep = 222, log_2-norm (real | extr) = ( 18 | 36 ), log_inf-norm (real | extr) = (  2 | 33 ), wit size = 6826. MB
# fold    : wdim =  5373952, rep =  26, log_2-norm (real | extr) = ( 26 | 28 ), log_inf-norm (real | extr) = ( 12 | 28 ), wit size = 3464. MB
# bdecomp : wdim =  5373952, rep = 104, log_2-norm (real | extr) = ( 18 | 18 ), log_inf-norm (real | extr) = (  2 | 18 ), wit size = 3198. MB
# norm    : wdim =  5373952, rep = 114, log_2-norm (real | extr) = ( 18 | 36 ), log_inf-norm (real | extr) = (  2 | 33 ), wit size = 3506. MB
# batch   : wdim =  5373952, rep = 114, log_2-norm (real | extr) = ( 18 | 36 ), log_inf-norm (real | extr) = (  2 | 33 ), wit size = 3506. MB
# split   : wdim =  2686976, rep = 228, log_2-norm (real | extr) = ( 18 | 36 ), log_inf-norm (real | extr) = (  2 | 33 ), wit size = 3506. MB
# fold    : wdim =  2686976, rep =  26, log_2-norm (real | extr) = ( 26 | 28 ), log_inf-norm (real | extr) = ( 12 | 28 ), wit size = 1732. MB
# bdecomp : wdim =  2686976, rep = 104, log_2-norm (real | extr) = ( 18 | 18 ), log_inf-norm (real | extr) = (  3 | 18 ), wit size = 2132. MB
# norm    : wdim =  2686976, rep = 113, log_2-norm (real | extr) = ( 18 | 36 ), log_inf-norm (real | extr) = (  3 | 33 ), wit size = 2316. MB
# batch   : wdim =  2686976, rep = 113, log_2-norm (real | extr) = ( 18 | 36 ), log_inf-norm (real | extr) = (  3 | 33 ), wit size = 2316. MB
# split   : wdim =  1343488, rep = 226, log_2-norm (real | extr) = ( 18 | 36 ), log_inf-norm (real | extr) = (  3 | 33 ), wit size = 2316. MB
# fold    : wdim =  1343488, rep =  26, log_2-norm (real | extr) = ( 26 | 28 ), log_inf-norm (real | extr) = ( 13 | 28 ), wit size = 932.8 MB
# bdecomp : wdim =  1343488, rep = 104, log_2-norm (real | extr) = ( 17 | 17 ), log_inf-norm (real | extr) = (  3 | 17 ), wit size = 1066. MB
# norm    : wdim =  1343488, rep = 113, log_2-norm (real | extr) = ( 17 | 35 ), log_inf-norm (real | extr) = (  3 | 32 ), wit size = 1158. MB
# batch   : wdim =  1343488, rep = 113, log_2-norm (real | extr) = ( 17 | 35 ), log_inf-norm (real | extr) = (  3 | 32 ), wit size = 1158. MB
# split   : wdim =   671744, rep = 226, log_2-norm (real | extr) = ( 17 | 35 ), log_inf-norm (real | extr) = (  3 | 32 ), wit size = 1158. MB
# fold    : wdim =   671744, rep =  26, log_2-norm (real | extr) = ( 25 | 27 ), log_inf-norm (real | extr) = ( 13 | 27 ), wit size = 466.4 MB
# bdecomp : wdim =   671744, rep = 104, log_2-norm (real | extr) = ( 17 | 17 ), log_inf-norm (real | extr) = (  3 | 17 ), wit size = 533.0 MB
# norm    : wdim =   671744, rep = 113, log_2-norm (real | extr) = ( 17 | 35 ), log_inf-norm (real | extr) = (  3 | 32 ), wit size = 579.1 MB
# batch   : wdim =   671744, rep = 113, log_2-norm (real | extr) = ( 17 | 35 ), log_inf-norm (real | extr) = (  3 | 32 ), wit size = 579.1 MB
# split   : wdim =   335872, rep = 226, log_2-norm (real | extr) = ( 17 | 35 ), log_inf-norm (real | extr) = (  3 | 32 ), wit size = 579.1 MB
# fold    : wdim =   335872, rep =  26, log_2-norm (real | extr) = ( 25 | 27 ), log_inf-norm (real | extr) = ( 13 | 27 ), wit size = 233.2 MB
# bdecomp : wdim =   335872, rep = 104, log_2-norm (real | extr) = ( 16 | 16 ), log_inf-norm (real | extr) = (  3 | 16 ), wit size = 266.5 MB
# norm    : wdim =   335872, rep = 112, log_2-norm (real | extr) = ( 16 | 34 ), log_inf-norm (real | extr) = (  3 | 31 ), wit size = 287.0 MB
# batch   : wdim =   335872, rep = 112, log_2-norm (real | extr) = ( 16 | 34 ), log_inf-norm (real | extr) = (  3 | 31 ), wit size = 287.0 MB
# split   : wdim =   167936, rep = 224, log_2-norm (real | extr) = ( 16 | 34 ), log_inf-norm (real | extr) = (  3 | 31 ), wit size = 287.0 MB
# fold    : wdim =   167936, rep =  26, log_2-norm (real | extr) = ( 24 | 26 ), log_inf-norm (real | extr) = ( 13 | 26 ), wit size = 116.6 MB
# bdecomp : wdim =   167936, rep = 104, log_2-norm (real | extr) = ( 16 | 16 ), log_inf-norm (real | extr) = (  3 | 16 ), wit size = 133.2 MB
# norm    : wdim =   167936, rep = 112, log_2-norm (real | extr) = ( 16 | 34 ), log_inf-norm (real | extr) = (  3 | 31 ), wit size = 143.5 MB
# batch   : wdim =   167936, rep = 112, log_2-norm (real | extr) = ( 16 | 34 ), log_inf-norm (real | extr) = (  3 | 31 ), wit size = 143.5 MB
# split   : wdim =    83968, rep = 224, log_2-norm (real | extr) = ( 16 | 34 ), log_inf-norm (real | extr) = (  3 | 31 ), wit size = 143.5 MB
# fold    : wdim =    83968, rep =  26, log_2-norm (real | extr) = ( 24 | 26 ), log_inf-norm (real | extr) = ( 13 | 26 ), wit size = 58.30 MB
# bdecomp : wdim =    83968, rep = 104, log_2-norm (real | extr) = ( 15 | 15 ), log_inf-norm (real | extr) = (  3 | 15 ), wit size = 66.62 MB
# norm    : wdim =    83968, rep = 112, log_2-norm (real | extr) = ( 15 | 33 ), log_inf-norm (real | extr) = (  3 | 30 ), wit size = 71.75 MB
# batch   : wdim =    83968, rep = 112, log_2-norm (real | extr) = ( 15 | 33 ), log_inf-norm (real | extr) = (  3 | 30 ), wit size = 71.75 MB
# split   : wdim =    41984, rep = 224, log_2-norm (real | extr) = ( 15 | 33 ), log_inf-norm (real | extr) = (  3 | 30 ), wit size = 71.75 MB
# fold    : wdim =    41984, rep =  26, log_2-norm (real | extr) = ( 23 | 25 ), log_inf-norm (real | extr) = ( 13 | 25 ), wit size = 29.15 MB
# bdecomp : wdim =    41984, rep = 104, log_2-norm (real | extr) = ( 15 | 15 ), log_inf-norm (real | extr) = (  3 | 15 ), wit size = 33.31 MB
# norm    : wdim =    41984, rep = 111, log_2-norm (real | extr) = ( 15 | 33 ), log_inf-norm (real | extr) = (  3 | 30 ), wit size = 35.55 MB
# batch   : wdim =    41984, rep = 111, log_2-norm (real | extr) = ( 15 | 33 ), log_inf-norm (real | extr) = (  3 | 30 ), wit size = 35.55 MB
# split   : wdim =    20992, rep = 222, log_2-norm (real | extr) = ( 15 | 33 ), log_inf-norm (real | extr) = (  3 | 30 ), wit size = 35.55 MB
# fold    : wdim =    20992, rep =  26, log_2-norm (real | extr) = ( 23 | 25 ), log_inf-norm (real | extr) = ( 13 | 25 ), wit size = 14.57 MB
# bdecomp : wdim =    20992, rep = 104, log_2-norm (real | extr) = ( 14 | 14 ), log_inf-norm (real | extr) = (  3 | 14 ), wit size = 16.66 MB
# norm    : wdim =    20992, rep = 111, log_2-norm (real | extr) = ( 14 | 32 ), log_inf-norm (real | extr) = (  3 | 29 ), wit size = 17.78 MB
# batch   : wdim =    20992, rep = 111, log_2-norm (real | extr) = ( 14 | 32 ), log_inf-norm (real | extr) = (  3 | 29 ), wit size = 17.78 MB
# split   : wdim =    10496, rep = 222, log_2-norm (real | extr) = ( 14 | 32 ), log_inf-norm (real | extr) = (  3 | 29 ), wit size = 17.78 MB
# fold    : wdim =    10496, rep =  26, log_2-norm (real | extr) = ( 22 | 24 ), log_inf-norm (real | extr) = ( 13 | 24 ), wit size = 7.287 MB
# bdecomp : wdim =    10496, rep = 104, log_2-norm (real | extr) = ( 14 | 14 ), log_inf-norm (real | extr) = (  3 | 14 ), wit size = 8.328 MB
# norm    : wdim =    10496, rep = 111, log_2-norm (real | extr) = ( 14 | 32 ), log_inf-norm (real | extr) = (  3 | 29 ), wit size = 8.889 MB
# batch   : wdim =    10496, rep = 111, log_2-norm (real | extr) = ( 14 | 32 ), log_inf-norm (real | extr) = (  3 | 29 ), wit size = 8.889 MB
# split   : wdim =     5248, rep = 222, log_2-norm (real | extr) = ( 14 | 32 ), log_inf-norm (real | extr) = (  3 | 29 ), wit size = 8.889 MB
# fold    : wdim =     5248, rep =  26, log_2-norm (real | extr) = ( 22 | 24 ), log_inf-norm (real | extr) = ( 13 | 24 ), wit size = 3.644 MB
# bdecomp : wdim =     5248, rep = 104, log_2-norm (real | extr) = ( 13 | 13 ), log_inf-norm (real | extr) = (  3 | 13 ), wit size = 4.164 MB
# norm    : wdim =     5248, rep = 111, log_2-norm (real | extr) = ( 13 | 30 ), log_inf-norm (real | extr) = (  3 | 18 ), wit size = 4.444 MB
# batch   : wdim =     5248, rep = 111, log_2-norm (real | extr) = ( 13 | 30 ), log_inf-norm (real | extr) = (  3 | 18 ), wit size = 4.444 MB
# split   : wdim =     2624, rep = 222, log_2-norm (real | extr) = ( 13 | 30 ), log_inf-norm (real | extr) = (  3 | 18 ), wit size = 4.444 MB
# fold    : wdim =     2624, rep =  26, log_2-norm (real | extr) = ( 21 | 21 ), log_inf-norm (real | extr) = ( 13 | 13 ), wit size = 1.822 MB
# finish  : True
#
# Costs:
# bdecomp : communication = 496.9 KB, soundness error = 2^-Infinity
# norm    : communication = 114.5 KB, soundness error = 2^-104
# batch   : communication = 0.0000 B, soundness error = 2^-120
# split   : communication = 777.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 526.5 KB, soundness error = 2^-Infinity
# norm    : communication = 112.8 KB, soundness error = 2^-105
# batch   : communication = 0.0000 B, soundness error = 2^-119
# split   : communication = 798.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 526.5 KB, soundness error = 2^-Infinity
# norm    : communication = 108.8 KB, soundness error = 2^-106
# batch   : communication = 0.0000 B, soundness error = 2^-119
# split   : communication = 791.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 526.5 KB, soundness error = 2^-Infinity
# norm    : communication = 112.1 KB, soundness error = 2^-107
# batch   : communication = 0.0000 B, soundness error = 2^-118
# split   : communication = 791.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 526.5 KB, soundness error = 2^-Infinity
# norm    : communication = 115.5 KB, soundness error = 2^-108
# batch   : communication = 0.0000 B, soundness error = 2^-118
# split   : communication = 791.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 526.5 KB, soundness error = 2^-Infinity
# norm    : communication = 110.0 KB, soundness error = 2^-109
# batch   : communication = 0.0000 B, soundness error = 2^-118
# split   : communication = 784.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 526.5 KB, soundness error = 2^-Infinity
# norm    : communication = 113.0 KB, soundness error = 2^-110
# batch   : communication = 0.0000 B, soundness error = 2^-117
# split   : communication = 784.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 526.5 KB, soundness error = 2^-Infinity
# norm    : communication = 116.0 KB, soundness error = 2^-111
# batch   : communication = 0.0000 B, soundness error = 2^-117
# split   : communication = 784.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 526.5 KB, soundness error = 2^-Infinity
# norm    : communication = 109.0 KB, soundness error = 2^-112
# batch   : communication = 0.0000 B, soundness error = 2^-117
# split   : communication = 777.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 526.5 KB, soundness error = 2^-Infinity
# norm    : communication = 111.6 KB, soundness error = 2^-113
# batch   : communication = 0.0000 B, soundness error = 2^-117
# split   : communication = 777.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 526.5 KB, soundness error = 2^-Infinity
# norm    : communication = 114.2 KB, soundness error = 2^-114
# batch   : communication = 0.0000 B, soundness error = 2^-117
# split   : communication = 777.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# bdecomp : communication = 526.5 KB, soundness error = 2^-Infinity
# norm    : communication = 116.9 KB, soundness error = 2^-115
# batch   : communication = 0.0000 B, soundness error = 2^-117
# split   : communication = 777.0 KB, soundness error = 2^-128
# fold    : communication = 0.0000 B, soundness error = 2^-86
# finish  : communication = 1.822 MB, soundness error = 2^-Infinity
#
# Total Cost: communication = 18.47 MB, soundness error = 2^-82
# Maximum log ell_2-norm (real | extr) = ( 27 | 36 ), log SIS norm bound = 37

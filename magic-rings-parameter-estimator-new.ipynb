# %%
from symbolic_variables import *
from gen_params import gen_ring_param, gen_sis_param, gen_sis_param_aggresive
from ring_params import *
from protocol import Protocol

# %%
## Strategy: 
##   - Opener: init->norm->batch->split->fold
##   - Loop: norm->batch->bdecomp->split->fold

ring_param = ring_param_60_16
sis_param = gen_sis_param(ring_param = ring_param, log_beta_sis = 40.1)
rep = 25
wit_rdim = 2**30/ring_param["phi"]/rep
beta_inf = 1
beta_2 = sqrt(wit_rdim * ring_param["phi"] * ring_param["fhat"]) * beta_inf
ell = 2
tdim = 4

protocol = Protocol(
    ring_param = ring_param,
    sis_param = sis_param,
    rep = rep, 
    wit_rdim = wit_rdim,  
    beta_2 = beta_2,
    beta_inf = beta_inf
)

opener = [("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
loop = [("bdecomp", {"ell":ell}), ("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
ops = opener + loop + loop + opener + loop + [("finish", {})]

for op, params in ops:
    protocol.execute(op, **params)
protocol.extract()
protocol.print()
# Out:
# Global parameters:
#   conductor   ring degree   subtractive set size   log modulus   log sis norm       Rq size
#   v_f         v_phi         v_C                    log(v_q)      log(v_beta_sis)    v_ringelq
#   60          16            12                     64            40.1000000000000   128.0 B
# Protocol history:
#   operation   #relations         witness dimension   bundle size   log witness norm can-2   log extration norm can-2   log witness norm coeff-inf   log extration norm coeff-inf   prover comm   witness size   soundness
#               (v_ntop, v_nbot)   v_wit_rdim          v_rep         log(v_beta_wit_2)        log(v_beta_ext_2)          log(2*v_beta_wit_inf)        log(2*v_beta_ext_inf)          v_pi          v_w            -log(v_snderr)
#   init        (62, 0)            67108864/25         25            16                       16                         1                            16                             0.0000 B      128.0 MB       +Infinity
#   norm        (62, 3)            67108864/25         41            18                       16                         1                            16                             139.4 KB      209.9 MB       106
#   batch       (62, 1)            67108864/25         41            18                       30                         1                            25                             139.4 KB      209.9 MB       106
#   split       (62, 1)            16777216/25         164           18                       30                         1                            25                             1.142 MB      209.9 MB       106
#   fold        (62, 1)            16777216/25         25            27                       29                         2                            25                             1.142 MB      64.00 MB       83
#   bdecomp     (62, 1)            16777216/25         50            18                       20                         1                            20                             1.334 MB      64.00 MB       83
#   norm        (62, 4)            16777216/25         65            18                       18                         1                            18                             1.474 MB      83.20 MB       83
#   batch       (62, 1)            16777216/25         65            18                       29                         1                            24                             1.474 MB      83.20 MB       83
#   split       (62, 1)            4194304/25          260           18                       29                         1                            24                             3.068 MB      83.20 MB       83
#   fold        (62, 1)            4194304/25          25            28                       28                         2                            24                             3.068 MB      16.00 MB       81
#   bdecomp     (62, 1)            4194304/25          50            17                       19                         1                            19                             3.261 MB      16.00 MB       81
#   norm        (62, 4)            4194304/25          64            17                       17                         1                            17                             3.392 MB      20.48 MB       81
#   batch       (62, 1)            4194304/25          64            17                       37                         1                            32                             3.392 MB      20.48 MB       81
#   split       (62, 1)            1048576/25          256           17                       37                         1                            32                             4.962 MB      20.48 MB       81
#   fold        (62, 1)            1048576/25          25            27                       36                         2                            32                             4.962 MB      4.000 MB       81
#   norm        (62, 4)            1048576/25          35            27                       27                         2                            27                             5.052 MB      5.600 MB       81
#   batch       (62, 1)            1048576/25          35            27                       27                         2                            22                             5.052 MB      5.600 MB       81
#   split       (62, 1)            262144/25           140           27                       27                         2                            22                             5.911 MB      5.600 MB       81
#   fold        (62, 1)            262144/25           25            37                       26                         3                            22                             5.911 MB      1.500 MB       80
#   bdecomp     (62, 1)            262144/25           50            15                       17                         1                            17                             6.103 MB      1.000 MB       80
#   norm        (62, 4)            262144/25           61            15                       15                         1                            15                             6.210 MB      1.220 MB       80
#   batch       (62, 1)            262144/25           61            15                       35                         1                            7                              6.210 MB      1.220 MB       80
#   split       (62, 1)            65536/25            244           15                       35                         1                            7                              7.706 MB      1.220 MB       80
#   fold        (62, 1)            65536/25            25            25                       34                         2                            7                              7.706 MB      256.0 KB       80
#   finish      (62, 0)            65536/25            0             25                       25                         2                            2                              7.956 MB      0.0000 B       80

# %%
## Strategy: 
##   - Opener: init->norm->batch->split->fold
##   - Loop: bdecomp->norm->batch->split->fold

ring_param = ring_param_24_8
sis_param = gen_sis_param(ring_param = ring_param, log_beta_sis = 36.9)
rep = 57
wit_rdim = 2**30/ring_param["phi"]/rep
beta_inf = 1
beta_2 = sqrt(wit_rdim * ring_param["phi"] * ring_param["fhat"]) * beta_inf
ell = 2
tdim = 2

protocol = Protocol(
    ring_param = ring_param,
    sis_param = sis_param,
    rep = rep, 
    wit_rdim = wit_rdim,  
    beta_2 = beta_2,
    beta_inf = beta_inf
)

opener = [("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
loop = [("bdecomp", {"ell":ell}), ("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
ops = opener + opener + loop + loop + opener + loop + opener + loop + [("finish", {})]

for op, params in ops:
    protocol.execute(op, **params)
protocol.extract()
protocol.print()
# Out:
# Global parameters:
#   conductor   ring degree   subtractive set size   log modulus   log sis norm       Rq size
#   v_f         v_phi         v_C                    log(v_q)      log(v_beta_sis)    v_ringelq
#   24          8             3                      64            36.9000000000000   64.00 B
# Protocol history:
#   operation   #relations         witness dimension   bundle size   log witness norm can-2   log extration norm can-2   log witness norm coeff-inf   log extration norm coeff-inf   prover comm   witness size   soundness
#               (v_ntop, v_nbot)   v_wit_rdim          v_rep         log(v_beta_wit_2)        log(v_beta_ext_2)          log(2*v_beta_wit_inf)        log(2*v_beta_ext_inf)          v_pi          v_w            -log(v_snderr)
#   init        (105, 0)           134217728/57        57            14                       14                         1                            14                             0.0000 B      128.0 MB       +Infinity
#   norm        (105, 3)           134217728/57        73            16                       14                         1                            14                             118.7 KB      163.9 MB       106
#   batch       (105, 1)           134217728/57        73            16                       35                         1                            31                             118.7 KB      163.9 MB       106
#   split       (105, 1)           67108864/57         146           16                       35                         1                            31                             611.4 KB      163.9 MB       106
#   fold        (105, 1)           67108864/57         57            27                       34                         2                            31                             611.4 KB      128.0 MB       84
#   norm        (105, 4)           67108864/57         68            27                       27                         2                            27                             697.1 KB      152.7 MB       84
#   batch       (105, 1)           67108864/57         68            27                       27                         2                            23                             697.1 KB      152.7 MB       84
#   split       (105, 1)           33554432/57         136           27                       27                         2                            23                             1.129 MB      152.7 MB       84
#   fold        (105, 1)           33554432/57         57            37                       27                         3                            23                             1.129 MB      96.00 MB       83
#   bdecomp     (105, 1)           33554432/57         114           17                       19                         1                            19                             1.498 MB      64.00 MB       83
#   norm        (105, 4)           33554432/57         128           17                       17                         1                            17                             1.612 MB      71.86 MB       83
#   batch       (105, 1)           33554432/57         128           17                       27                         1                            23                             1.612 MB      71.86 MB       83
#   split       (105, 1)           16777216/57         256           17                       27                         1                            23                             2.456 MB      71.86 MB       83
#   fold        (105, 1)           16777216/57         57            28                       27                         2                            23                             2.456 MB      32.00 MB       82
#   bdecomp     (105, 1)           16777216/57         114           17                       19                         1                            19                             2.824 MB      32.00 MB       82
#   norm        (105, 4)           16777216/57         128           17                       17                         1                            17                             2.938 MB      35.93 MB       82
#   batch       (105, 1)           16777216/57         128           17                       36                         1                            32                             2.938 MB      35.93 MB       82
#   split       (105, 1)           8388608/57          256           17                       36                         1                            32                             3.782 MB      35.93 MB       82
#   fold        (105, 1)           8388608/57          57            28                       36                         2                            32                             3.782 MB      16.00 MB       81
#   norm        (105, 4)           8388608/57          67            28                       28                         2                            28                             3.859 MB      18.81 MB       81
#   batch       (105, 1)           8388608/57          67            28                       26                         2                            22                             3.859 MB      18.81 MB       81
#   split       (105, 1)           4194304/57          134           28                       26                         2                            22                             4.301 MB      18.81 MB       81
#   fold        (105, 1)           4194304/57          57            38                       25                         3                            22                             4.301 MB      12.00 MB       81
#   bdecomp     (105, 1)           4194304/57          114           16                       18                         1                            18                             4.669 MB      8.000 MB       81
#   norm        (105, 4)           4194304/57          127           16                       16                         1                            16                             4.777 MB      8.912 MB       81
#   batch       (105, 1)           4194304/57          127           16                       35                         1                            31                             4.777 MB      8.912 MB       81
#   split       (105, 1)           2097152/57          254           16                       35                         1                            31                             5.614 MB      8.912 MB       81
#   fold        (105, 1)           2097152/57          57            27                       35                         2                            31                             5.614 MB      4.000 MB       81
#   norm        (105, 4)           2097152/57          66            27                       27                         2                            27                             5.684 MB      4.632 MB       81
#   batch       (105, 1)           2097152/57          66            27                       25                         2                            21                             5.684 MB      4.632 MB       81
#   split       (105, 1)           1048576/57          132           27                       25                         2                            21                             6.119 MB      4.632 MB       81
#   fold        (105, 1)           1048576/57          57            37                       24                         3                            21                             6.119 MB      3.000 MB       80
#   bdecomp     (105, 1)           1048576/57          114           15                       17                         1                            17                             6.488 MB      2.000 MB       80
#   norm        (105, 4)           1048576/57          125           15                       15                         1                            15                             6.582 MB      2.193 MB       80
#   batch       (105, 1)           1048576/57          125           15                       34                         1                            6                              6.582 MB      2.193 MB       80
#   split       (105, 1)           524288/57           250           15                       34                         1                            6                              7.406 MB      2.193 MB       80
#   fold        (105, 1)           524288/57           57            26                       34                         2                            6                              7.406 MB      1.000 MB       80
#   finish      (105, 0)           524288/57           0             26                       26                         2                            2                              8.406 MB      0.0000 B       80

# %%
## Strategy: 
##   - Opener: init->norm->batch->split->fold
##   - Loop: norm->batch->bdecomp->split->fold

ring_param = ring_param_60_16
sis_param = gen_sis_param(ring_param = ring_param, log_beta_sis = 40.1)
rep = 25
wit_rdim = 2**30/ring_param["phi"]/rep
beta_inf = 127
beta_2 = sqrt(wit_rdim * ring_param["phi"] * ring_param["fhat"]) * beta_inf
ell = 2
tdim = 4

protocol = Protocol(
    ring_param = ring_param,
    sis_param = sis_param,
    rep = rep, 
    wit_rdim = wit_rdim,  
    beta_2 = beta_2,
    beta_inf = beta_inf
)

opener = [("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
loop = [("bdecomp", {"ell":ell}), ("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
ops = opener + loop + loop + opener + loop + [("finish", {})]

for op, params in ops:
    protocol.execute(op, **params)
protocol.extract()
protocol.print()
# Out:
# Global parameters:
#   conductor   ring degree   subtractive set size   log modulus   log sis norm       Rq size
#   v_f         v_phi         v_C                    log(v_q)      log(v_beta_sis)    v_ringelq
#   60          16            12                     64            40.1000000000000   128.0 B
# Protocol history:
#   operation   #relations         witness dimension   bundle size   log witness norm can-2   log extration norm can-2   log witness norm coeff-inf   log extration norm coeff-inf   prover comm   witness size   soundness
#               (v_ntop, v_nbot)   v_wit_rdim          v_rep         log(v_beta_wit_2)        log(v_beta_ext_2)          log(2*v_beta_wit_inf)        log(2*v_beta_ext_inf)          v_pi          v_w            -log(v_snderr)
#   init        (62, 0)            67108864/25         25            23                       23                         7                            23                             0.0000 B      896.0 MB       +Infinity
#   norm        (62, 3)            67108864/25         30            24                       23                         7                            23                             50.00 KB      1075. MB       106
#   batch       (62, 1)            67108864/25         30            24                       35                         7                            31                             50.00 KB      1075. MB       106
#   split       (62, 1)            16777216/25         120           24                       35                         7                            31                             803.8 KB      1075. MB       106
#   fold        (62, 1)            16777216/25         25            33                       34                         8                            31                             803.8 KB      256.0 MB       83
#   bdecomp     (62, 1)            16777216/25         50            21                       26                         4                            26                             1001. KB      256.0 MB       83
#   norm        (62, 4)            16777216/25         57            21                       21                         4                            21                             1.052 MB      291.8 MB       83
#   batch       (62, 1)            16777216/25         57            21                       31                         4                            26                             1.052 MB      291.8 MB       83
#   split       (62, 1)            4194304/25          228           21                       31                         4                            26                             2.450 MB      291.8 MB       83
#   fold        (62, 1)            4194304/25          25            31                       30                         5                            26                             2.450 MB      40.00 MB       82
#   bdecomp     (62, 1)            4194304/25          50            18                       21                         2                            21                             2.643 MB      32.00 MB       82
#   norm        (62, 4)            4194304/25          59            18                       18                         2                            18                             2.734 MB      37.76 MB       82
#   batch       (62, 1)            4194304/25          59            18                       38                         2                            34                             2.734 MB      37.76 MB       82
#   split       (62, 1)            1048576/25          236           18                       38                         2                            34                             4.181 MB      37.76 MB       82
#   fold        (62, 1)            1048576/25          25            29                       37                         3                            34                             4.181 MB      6.000 MB       81
#   norm        (62, 4)            1048576/25          32            29                       29                         3                            29                             4.247 MB      7.680 MB       81
#   batch       (62, 1)            1048576/25          32            29                       28                         3                            23                             4.247 MB      7.680 MB       81
#   split       (62, 1)            262144/25           128           29                       28                         3                            23                             5.032 MB      7.680 MB       81
#   fold        (62, 1)            262144/25           25            38                       27                         4                            23                             5.032 MB      2.000 MB       81
#   bdecomp     (62, 1)            262144/25           50            16                       18                         2                            18                             5.224 MB      2.000 MB       81
#   norm        (62, 4)            262144/25           59            16                       16                         2                            16                             5.315 MB      2.360 MB       81
#   batch       (62, 1)            262144/25           59            16                       36                         2                            8                              5.315 MB      2.360 MB       81
#   split       (62, 1)            65536/25            236           16                       36                         2                            8                              6.763 MB      2.360 MB       81
#   fold        (62, 1)            65536/25            25            26                       35                         3                            8                              6.763 MB      384.0 KB       80
#   finish      (62, 0)            65536/25            0             26                       26                         3                            3                              7.138 MB      0.0000 B       80

# %%
## Strategy: 
##   - Opener: init->norm->batch->split->fold
##   - Loop: norm->batch->bdecomp->split->fold

ring_param = ring_param_60_16
sis_param = gen_sis_param(ring_param = ring_param, log_beta_sis = 40.1)
rep = 25
wit_rdim = 2**32/ring_param["phi"]/rep
beta_inf = 127
beta_2 = sqrt(wit_rdim * ring_param["phi"] * ring_param["fhat"]) * beta_inf
ell = 2
tdim = 4

protocol = Protocol(
    ring_param = ring_param,
    sis_param = sis_param,
    rep = rep, 
    wit_rdim = wit_rdim,  
    beta_2 = beta_2,
    beta_inf = beta_inf
)

opener = [("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
loop = [("bdecomp", {"ell":ell}), ("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
ops = opener + loop + loop + opener + loop + [("finish", {})]

for op, params in ops:
    protocol.execute(op, **params)
protocol.extract()
protocol.print()
# Out:
# Global parameters:
#   conductor   ring degree   subtractive set size   log modulus   log sis norm       Rq size
#   v_f         v_phi         v_C                    log(v_q)      log(v_beta_sis)    v_ringelq
#   60          16            12                     64            40.1000000000000   128.0 B
# Protocol history:
#   operation   #relations         witness dimension   bundle size   log witness norm can-2   log extration norm can-2   log witness norm coeff-inf   log extration norm coeff-inf   prover comm   witness size   soundness
#               (v_ntop, v_nbot)   v_wit_rdim          v_rep         log(v_beta_wit_2)        log(v_beta_ext_2)          log(2*v_beta_wit_inf)        log(2*v_beta_ext_inf)          v_pi          v_w            -log(v_snderr)
#   init        (62, 0)            268435456/25        25            24                       24                         7                            24                             0.0000 B      3584. MB       +Infinity
#   norm        (62, 3)            268435456/25        31            25                       24                         7                            24                             58.12 KB      4444. MB       104
#   batch       (62, 1)            268435456/25        31            25                       36                         7                            32                             58.12 KB      4444. MB       104
#   split       (62, 1)            67108864/25         124           25                       36                         7                            32                             837.0 KB      4444. MB       104
#   fold        (62, 1)            67108864/25         25            34                       35                         8                            32                             837.0 KB      1024. MB       83
#   bdecomp     (62, 1)            67108864/25         50            22                       27                         4                            27                             1.010 MB      1024. MB       83
#   norm        (62, 4)            67108864/25         58            22                       22                         4                            22                             1.092 MB      1188. MB       83
#   batch       (62, 1)            67108864/25         58            22                       32                         4                            27                             1.092 MB      1188. MB       83
#   split       (62, 1)            16777216/25         232           22                       32                         4                            27                             2.516 MB      1188. MB       83
#   fold        (62, 1)            16777216/25         25            32                       31                         5                            27                             2.516 MB      160.0 MB       82
#   bdecomp     (62, 1)            16777216/25         50            19                       22                         2                            22                             2.708 MB      128.0 MB       82
#   norm        (62, 4)            16777216/25         60            19                       19                         2                            19                             2.807 MB      153.6 MB       82
#   batch       (62, 1)            16777216/25         60            19                       40                         2                            35                             2.807 MB      153.6 MB       82
#   split       (62, 1)            4194304/25          240           19                       40                         2                            35                             4.279 MB      153.6 MB       82
#   fold        (62, 1)            4194304/25          25            30                       39                         3                            35                             4.279 MB      24.00 MB       81
#   norm        (62, 4)            4194304/25          33            30                       30                         3                            30                             4.352 MB      31.68 MB       81
#   batch       (62, 1)            4194304/25          33            30                       29                         3                            24                             4.352 MB      31.68 MB       81
#   split       (62, 1)            1048576/25          132           30                       29                         3                            24                             5.162 MB      31.68 MB       81
#   fold        (62, 1)            1048576/25          25            39                       28                         4                            24                             5.162 MB      8.000 MB       81
#   bdecomp     (62, 1)            1048576/25          50            17                       19                         2                            19                             5.354 MB      8.000 MB       81
#   norm        (62, 4)            1048576/25          60            17                       17                         2                            17                             5.453 MB      9.600 MB       81
#   batch       (62, 1)            1048576/25          60            17                       37                         2                            8                              5.453 MB      9.600 MB       81
#   split       (62, 1)            262144/25           240           17                       37                         2                            8                              6.925 MB      9.600 MB       81
#   fold        (62, 1)            262144/25           25            27                       36                         3                            8                              6.925 MB      1.500 MB       80
#   finish      (62, 0)            262144/25           0             27                       27                         3                            3                              8.425 MB      0.0000 B       80

# %%
from symbolic_variables import *
from gen_params import gen_ring_param, gen_sis_param, gen_sis_param_aggresive
from ring_params import *
from protocol import Protocol

# %%
ring_param = ring_param_2520_576
sis_param = gen_sis_param(ring_param = ring_param, log_beta_sis = 43)
rep = 11
wit_rdim = 2**30/ring_param["phi"]/rep
beta_inf = 1
beta_2 = sqrt(wit_rdim * ring_param["phi"] * ring_param["fhat"]) * beta_inf
ell = 2
tdim = 2

# %%
protocol = Protocol(
    ring_param = ring_param,
    sis_param = sis_param,
    rep = rep, 
    wit_rdim = wit_rdim,  
    beta_2 = beta_2,
    beta_inf = beta_inf
)

opener = [("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
loop = [("bdecomp", {"ell":ell}), ("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
ops = opener + 4 * loop + [("finish", {})]

for op, params in ops:
    protocol.execute(op, **params)
protocol.extract()
protocol.print()
# Out:
# Global parameters:
#   conductor   ring degree   subtractive set size   log modulus   log sis norm      Rq size
#   v_f         v_phi         v_C                    log(v_q)      log(v_beta_sis)   v_ringelq
#   2520        576           360                    64            43                4 KB
# Protocol history:
#   operation   #relations         witness dimension   bundle size   log witness norm can-2   log extration norm can-2   log witness norm coeff-inf   log extration norm coeff-inf   prover comm   witness size   soundness
#               (v_ntop, v_nbot)   v_wit_rdim          v_rep         log(v_beta_wit_2)        log(v_beta_ext_2)          log(2*v_beta_wit_inf)        log(2*v_beta_ext_inf)          v_pi          v_w            -log(v_snderr)
#   init        (2, 0)             16777216/99         11            19                       19                         1                            19                             0 B           128 MB         +Infinity
#   norm        (2, 3)             16777216/99         28            21                       19                         1                            19                             531 KB        325 MB         110
#   batch       (2, 1)             16777216/99         28            21                       37                         1                            33                             531 KB        325 MB         110
#   split       (2, 1)             8388608/99          56            21                       37                         1                            33                             909 KB        325 MB         110
#   fold        (2, 1)             8388608/99          11            29                       36                         2                            33                             3 MB          128 MB         88
#   bdecomp     (2, 1)             8388608/99          22            21                       23                         1                            23                             3 MB          128 MB         88
#   norm        (2, 4)             8388608/99          39            21                       21                         1                            21                             4 MB          226 MB         88
#   batch       (2, 1)             8388608/99          39            21                       37                         1                            33                             4 MB          226 MB         88
#   split       (2, 1)             4194304/99          78            21                       37                         1                            33                             4 MB          226 MB         88
#   fold        (2, 1)             4194304/99          11            29                       36                         2                            33                             8 MB          64 MB          87
#   bdecomp     (2, 1)             4194304/99          22            21                       23                         1                            23                             8 MB          64 MB          87
#   norm        (2, 4)             4194304/99          38            21                       21                         1                            21                             9 MB          110 MB         87
#   batch       (2, 1)             4194304/99          38            21                       36                         1                            32                             9 MB          110 MB         87
#   split       (2, 1)             2097152/99          76            21                       36                         1                            32                             10 MB         110 MB         87
#   fold        (2, 1)             2097152/99          11            29                       36                         2                            32                             13 MB         32 MB          86
#   bdecomp     (2, 1)             2097152/99          22            20                       22                         1                            22                             13 MB         32 MB          86
#   norm        (2, 4)             2097152/99          37            20                       20                         1                            20                             14 MB         53 MB          86
#   batch       (2, 1)             2097152/99          37            20                       36                         1                            32                             14 MB         53 MB          86
#   split       (2, 1)             1048576/99          74            20                       36                         1                            32                             15 MB         53 MB          86
#   fold        (2, 1)             1048576/99          11            28                       35                         2                            32                             18 MB         16 MB          86
#   bdecomp     (2, 1)             1048576/99          22            20                       22                         1                            22                             18 MB         16 MB          86
#   norm        (2, 4)             1048576/99          37            20                       20                         1                            20                             19 MB         26 MB          86
#   batch       (2, 1)             1048576/99          37            20                       42                         1                            12                             19 MB         26 MB          86
#   split       (2, 1)             524288/99           74            20                       42                         1                            12                             20 MB         26 MB          86
#   fold        (2, 1)             524288/99           11            28                       41                         2                            12                             23 MB         8 MB           85
#   finish      (2, 0)             524288/99           0             28                       28                         2                            2                              31 MB         0 B            85

# %% [markdown]
# ## TODO
# - Cross-check protocol costs once they are fixed in the paper.
# - Fill in the correct costs for subtractive sets i.e. size, expansion factor, inverse expansion factor, etc.

# %%
from symbolic_variables import *
from gen_params import gen_ring_param, gen_sis_param, gen_sis_param_aggresive
from ring_params import *
from protocol import Protocol
from util import pretty_size

# %%
f = 5544
log_q = 110
ring_param = {
     'f': f,
     'fhat': f/2,
     'phi': euler_phi(f),
     'q': 2 ^ log_q,
     'log_q': log_q,
     'Rq_size': log_q * euler_phi(f),
     'e': 2,
     'C': f / 11,
     'gamma_2': 1,
     'theta_2': ceil(f/(2 * sqrt(2))),
     'gamma_inf': 2,
     'theta_inf': f,
     'ring_exp_inf': ceil(f/(2 * sqrt(2)))
}


sis_param = gen_sis_param(ring_param = ring_param, log_beta_sis = 65)
print(sis_param)
rep = 1
wit_rdim = 2**22
beta_inf = 20
beta_2 = sqrt(wit_rdim * ring_param["phi"] * ring_param["fhat"]) * beta_inf
tdim = 8
ell = 2

pareller_reps = 18

num_round = 3
error = num_round * (1 / ring_param['C'])
assert error^pareller_reps < 2^(-128)


protocol = Protocol(
    ring_param = ring_param,
    sis_param = sis_param,
    rep = rep, 
    wit_rdim = wit_rdim,  
    beta_2 = beta_2,
    beta_inf = beta_inf
)

loop = [
    ("norm", {}), 
    ("batch", {}),
    ("fold", {"repout":1}), 
    ("bdecomp", {"ell":ell}), 
    ("split", {"tdim":tdim}), 
    ("fold", {"repout":1}), 
]
ops = num_round * loop + [("finish", {})]

for op, params in ops:
    protocol.execute(op, **params)

protocol.extract()
protocol.print()

comm  = protocol.history[len(protocol.history) - 1].prover_comm
print("TOTAL COMMUNICATION: " +  pretty_size(comm * pareller_reps))
# Out:
# {'n': 2, 'log_beta_sis': 65}
# Global parameters:
#   conductor   ring degree   subtractive set size   log modulus   log sis norm      Rq size
#   v_f         v_phi         v_C                    log(v_q)      log(v_beta_sis)   v_ringelq
#   5544        1440          504                    110           65                19.34 KB
# Protocol history:
#   operation   #relations         witness dimension   bundle size   log witness norm can-2   log extration norm can-2   log witness norm coeff-inf   log extration norm coeff-inf   prover comm   witness size   soundness
#               (v_ntop, v_nbot)   v_wit_rdim          v_rep         log(v_beta_wit_2)        log(v_beta_ext_2)          log(2*v_beta_wit_inf)        log(2*v_beta_ext_inf)          v_pi          v_w            -log(v_snderr)
#   init        (2, 0)             4194304             1             27                       27                         5                            27                             0.0000 B      3600. MB       +Infinity
#   norm        (2, 3)             4194304             9             28                       27                         5                            27                             831.4 KB      32400. MB      197
#   batch       (2, 1)             4194304             9             28                       61                         5                            59                             831.4 KB      32400. MB      197
#   fold        (2, 1)             4194304             1             32                       61                         6                            59                             831.4 KB      4320. MB       6
#   bdecomp     (2, 1)             4194304             2             25                       48                         3                            46                             889.5 KB      4320. MB       6
#   split       (2, 1)             524288              16            25                       45                         3                            43                             3.777 MB      4320. MB       6
#   fold        (2, 1)             524288              1             29                       43                         4                            43                             3.777 MB      360.0 MB       5
#   norm        (2, 4)             524288              10            29                       29                         4                            29                             4.853 MB      3600. MB       5
#   batch       (2, 1)             524288              10            29                       59                         4                            57                             4.853 MB      3600. MB       5
#   fold        (2, 1)             524288              1             32                       59                         5                            57                             4.853 MB      450.0 MB       4
#   bdecomp     (2, 1)             524288              2             23                       45                         2                            43                             4.910 MB      360.0 MB       4
#   split       (2, 1)             65536               16            23                       42                         2                            40                             7.817 MB      360.0 MB       4
#   fold        (2, 1)             65536               1             27                       41                         3                            40                             7.817 MB      33.75 MB       4
#   norm        (2, 4)             65536               10            27                       27                         3                            27                             8.894 MB      337.5 MB       4
#   batch       (2, 1)             65536               10            27                       57                         3                            32                             8.894 MB      337.5 MB       4
#   fold        (2, 1)             65536               1             30                       57                         4                            32                             8.894 MB      45.00 MB       4
#   bdecomp     (2, 1)             65536               2             21                       43                         2                            19                             8.950 MB      45.00 MB       4
#   split       (2, 1)             8192                16            21                       41                         2                            16                             11.86 MB      45.00 MB       4
#   fold        (2, 1)             8192                1             25                       39                         3                            16                             11.86 MB      4.219 MB       3
#   finish      (2, 0)             8192                0             25                       25                         3                            3                              16.08 MB      0.0000 B       3
# TOTAL COMMUNICATION: 289.4 MB

# %%
f = 27720
log_q = 100
ring_param = {
     'f': f,
     'fhat': f/2,
     'phi': euler_phi(f),
     'q': 2 ^ log_q,
     'log_q': log_q,
     'Rq_size': log_q * euler_phi(f),
     'e': 2,
     'C': f / 11,
     'gamma_2': 1,
     'theta_2': ceil(f/(2 * sqrt(2))),
     'gamma_inf': 2,
     'theta_inf': f,
     'ring_exp_inf': ceil(f/(2 * sqrt(2)))
}


sis_param = gen_sis_param(ring_param = ring_param, log_beta_sis = 70)
print(sis_param)
rep = 1
wit_rdim = 2**22
beta_inf = 20
beta_2 = sqrt(wit_rdim * ring_param["phi"] * ring_param["fhat"]) * beta_inf
tdim = 8
ell = 2

pareller_reps = 14

num_round = 3
error = num_round * (1 / ring_param['C'])
assert error^pareller_reps < 2^(-128)


protocol = Protocol(
    ring_param = ring_param,
    sis_param = sis_param,
    rep = rep, 
    wit_rdim = wit_rdim,  
    beta_2 = beta_2,
    beta_inf = beta_inf
)

loop = [
    ("norm", {}), 
    ("batch", {}),
    ("fold", {"repout":1}), 
    ("bdecomp", {"ell":ell}), 
    ("split", {"tdim":tdim}), 
    ("fold", {"repout":1}), 
]
ops = num_round * loop + [("finish", {})]

for op, params in ops:
    protocol.execute(op, **params)

protocol.extract()
protocol.print()

comm  = protocol.history[len(protocol.history) - 1].prover_comm
print("TOTAL COMMUNICATION: " +  pretty_size(comm * pareller_reps))
# Out:
# {'n': 1, 'log_beta_sis': 70}
# Global parameters:
#   conductor   ring degree   subtractive set size   log modulus   log sis norm      Rq size
#   v_f         v_phi         v_C                    log(v_q)      log(v_beta_sis)   v_ringelq
#   27720       5760          2520                   100           70                70.31 KB
# Protocol history:
#   operation   #relations         witness dimension   bundle size   log witness norm can-2   log extration norm can-2   log witness norm coeff-inf   log extration norm coeff-inf   prover comm   witness size   soundness
#               (v_ntop, v_nbot)   v_wit_rdim          v_rep         log(v_beta_wit_2)        log(v_beta_ext_2)          log(2*v_beta_wit_inf)        log(2*v_beta_ext_inf)          v_pi          v_w            -log(v_snderr)
#   init        (1, 0)             4194304             1             29                       29                         5                            29                             0.0000 B      14400. MB      +Infinity
#   norm        (1, 3)             4194304             10            31                       29                         5                            29                             2.678 MB      144000. MB     177
#   batch       (1, 1)             4194304             10            31                       68                         5                            66                             2.678 MB      144000. MB     177
#   fold        (1, 1)             4194304             1             34                       68                         6                            66                             2.678 MB      17280. MB      8
#   bdecomp     (1, 1)             4194304             2             27                       52                         3                            50                             2.815 MB      17280. MB      8
#   split       (1, 1)             524288              16            27                       49                         3                            47                             12.43 MB      17280. MB      8
#   fold        (1, 1)             524288              1             31                       48                         4                            47                             12.43 MB      1440. MB       7
#   norm        (1, 4)             524288              11            31                       31                         4                            31                             16.07 MB      15840. MB      7
#   batch       (1, 1)             524288              11            31                       66                         4                            64                             16.07 MB      15840. MB      7
#   fold        (1, 1)             524288              1             35                       66                         5                            64                             16.07 MB      1800. MB       7
#   bdecomp     (1, 1)             524288              2             25                       50                         2                            48                             16.20 MB      1440. MB       7
#   split       (1, 1)             65536               16            25                       47                         2                            45                             25.82 MB      1440. MB       7
#   fold        (1, 1)             65536               1             29                       45                         3                            45                             25.82 MB      135.0 MB       6
#   norm        (1, 4)             65536               11            29                       29                         3                            29                             29.46 MB      1485. MB       6
#   batch       (1, 1)             65536               11            29                       64                         3                            37                             29.46 MB      1485. MB       6
#   fold        (1, 1)             65536               1             33                       64                         4                            37                             29.46 MB      180.0 MB       6
#   bdecomp     (1, 1)             65536               2             23                       48                         2                            21                             29.59 MB      180.0 MB       6
#   split       (1, 1)             8192                16            23                       45                         2                            18                             39.21 MB      180.0 MB       6
#   fold        (1, 1)             8192                1             27                       44                         3                            18                             39.21 MB      16.88 MB       5
#   finish      (1, 0)             8192                0             27                       27                         3                            3                              56.08 MB      0.0000 B       5
# TOTAL COMMUNICATION: 785.2 MB

# %%
from symbolic_variables import *
from gen_params import gen_ring_param, gen_sis_param, gen_sis_param_aggresive
from ring_params import *
from protocol import Protocol

# %%
## Strategy: 
##   - Opener: init->norm->batch->split->fold
##   - Loop: bdecomp->norm->batch->split->fold

ring_param = ring_param_60_16
sis_param = gen_sis_param(ring_param = ring_param, log_beta_sis = 35.6)
print(sis_param)
rep = 25
wit_rdim = 2**30/ring_param["phi"]/rep
print(float(log(wit_rdim, 2)))
beta_inf = 1
beta_2 = sqrt(wit_rdim * ring_param["phi"] * ring_param["fhat"]) * beta_inf
ell = 2
tdim = 2

protocol = Protocol(
    ring_param = ring_param,
    sis_param = sis_param,
    rep = rep, 
    wit_rdim = wit_rdim,  
    beta_2 = beta_2,
    beta_inf = beta_inf
)

loop_short = [("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
loop = [("bdecomp", {"ell":ell}), ("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
ops = loop_short + loop_short + loop + loop + loop + loop + loop_short + loop + [("finish", {})]

for op, params in ops:
    protocol.execute(op, **params)
protocol.extract()
protocol.print()
# Out:
# {'n': 49, 'log_beta_sis': 35.6000000000000}
# 21.356143810225277
# Global parameters:
#   conductor   ring degree   subtractive set size   log modulus   log sis norm       Rq size
#   v_f         v_phi         v_C                    log(v_q)      log(v_beta_sis)    v_ringelq
#   60          16            12                     64            35.6000000000000   128.0 B
# Protocol history:
#   operation   #relations         witness dimension   bundle size   log witness norm can-2   log extration norm can-2   log witness norm coeff-inf   log extration norm coeff-inf   prover comm   witness size   soundness
#               (v_ntop, v_nbot)   v_wit_rdim          v_rep         log(v_beta_wit_2)        log(v_beta_ext_2)          log(2*v_beta_wit_inf)        log(2*v_beta_ext_inf)          v_pi          v_w            -log(v_snderr)
#   init        (49, 0)            67108864/25         25            16                       16                         1                            16                             0.0000 B      128.0 MB       +Infinity
#   norm        (49, 3)            67108864/25         41            18                       16                         1                            16                             113.4 KB      209.9 MB       106
#   batch       (49, 1)            67108864/25         41            18                       35                         1                            31                             113.4 KB      209.9 MB       106
#   split       (49, 1)            33554432/25         82            18                       35                         1                            31                             379.9 KB      209.9 MB       106
#   fold        (49, 1)            33554432/25         25            26                       35                         2                            31                             379.9 KB      128.0 MB       84
#   norm        (49, 4)            33554432/25         37            26                       26                         2                            26                             468.8 KB      189.4 MB       84
#   batch       (49, 1)            33554432/25         37            26                       29                         2                            25                             468.8 KB      189.4 MB       84
#   split       (49, 1)            16777216/25         74            26                       29                         2                            25                             709.2 KB      189.4 MB       84
#   fold        (49, 1)            16777216/25         25            35                       28                         3                            25                             709.2 KB      96.00 MB       83
#   bdecomp     (49, 1)            16777216/25         50            18                       20                         1                            20                             865.5 KB      64.00 MB       83
#   norm        (49, 4)            16777216/25         65            18                       18                         1                            18                             983.6 KB      83.20 MB       83
#   batch       (49, 1)            16777216/25         65            18                       29                         1                            25                             983.6 KB      83.20 MB       83
#   split       (49, 1)            8388608/25          130           18                       29                         1                            25                             1.373 MB      83.20 MB       83
#   fold        (49, 1)            8388608/25          25            27                       28                         2                            25                             1.373 MB      32.00 MB       82
#   bdecomp     (49, 1)            8388608/25          50            18                       20                         1                            20                             1.526 MB      32.00 MB       82
#   norm        (49, 4)            8388608/25          65            18                       18                         1                            18                             1.641 MB      41.60 MB       82
#   batch       (49, 1)            8388608/25          65            18                       28                         1                            24                             1.641 MB      41.60 MB       82
#   split       (49, 1)            4194304/25          130           18                       28                         1                            24                             2.054 MB      41.60 MB       82
#   fold        (49, 1)            4194304/25          25            27                       28                         2                            24                             2.054 MB      16.00 MB       81
#   bdecomp     (49, 1)            4194304/25          50            17                       19                         1                            19                             2.206 MB      16.00 MB       81
#   norm        (49, 4)            4194304/25          64            17                       17                         1                            17                             2.315 MB      20.48 MB       81
#   batch       (49, 1)            4194304/25          64            17                       28                         1                            24                             2.315 MB      20.48 MB       81
#   split       (49, 1)            2097152/25          128           17                       28                         1                            24                             2.721 MB      20.48 MB       81
#   fold        (49, 1)            2097152/25          25            26                       27                         2                            24                             2.721 MB      8.000 MB       81
#   bdecomp     (49, 1)            2097152/25          50            17                       19                         1                            19                             2.874 MB      8.000 MB       81
#   norm        (49, 4)            2097152/25          63            17                       17                         1                            17                             2.976 MB      10.08 MB       81
#   batch       (49, 1)            2097152/25          63            17                       35                         1                            31                             2.976 MB      10.08 MB       81
#   split       (49, 1)            1048576/25          126           17                       35                         1                            31                             3.376 MB      10.08 MB       81
#   fold        (49, 1)            1048576/25          25            26                       34                         2                            31                             3.376 MB      4.000 MB       81
#   norm        (49, 4)            1048576/25          35            26                       26                         2                            26                             3.450 MB      5.600 MB       81
#   batch       (49, 1)            1048576/25          35            26                       26                         2                            23                             3.450 MB      5.600 MB       81
#   split       (49, 1)            524288/25           70            26                       26                         2                            23                             3.672 MB      5.600 MB       81
#   fold        (49, 1)            524288/25           25            34                       26                         3                            23                             3.672 MB      3.000 MB       81
#   bdecomp     (49, 1)            524288/25           50            16                       18                         1                            18                             3.825 MB      2.000 MB       81
#   norm        (49, 4)            524288/25           62            16                       16                         1                            16                             3.921 MB      2.480 MB       81
#   batch       (49, 1)            524288/25           62            16                       34                         1                            7                              3.921 MB      2.480 MB       81
#   split       (49, 1)            262144/25           124           16                       34                         1                            7                              4.314 MB      2.480 MB       81
#   fold        (49, 1)            262144/25           25            25                       33                         2                            7                              4.314 MB      1.000 MB       80
#   finish      (49, 0)            262144/25           0             25                       25                         2                            2                              5.314 MB      0.0000 B       80

# %%
## Strategy: 
##   - Opener: init->norm->batch->split->fold
##   - Loop: bdecomp->norm->batch->split->fold

ring_param = ring_param_60_16
sis_param = gen_sis_param(ring_param = ring_param, log_beta_sis = 38.8)
print(sis_param)
rep = 25
wit_rdim = 2**30/ring_param["phi"]/rep
print(float(log(wit_rdim, 2)))
beta_inf = 1023
beta_2 = sqrt(wit_rdim * ring_param["phi"] * ring_param["fhat"]) * beta_inf
ell = 2
tdim = 2

protocol = Protocol(
    ring_param = ring_param,
    sis_param = sis_param,
    rep = rep, 
    wit_rdim = wit_rdim,  
    beta_2 = beta_2,
    beta_inf = beta_inf
)

loop_short = [("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
loop = [("bdecomp", {"ell":ell}), ("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
ops = loop_short + loop + loop + loop_short + loop + loop + loop_short + loop + loop + [("finish", {})]

for op, params in ops:
    protocol.execute(op, **params)
protocol.extract()
protocol.print()
# Out:
# {'n': 59, 'log_beta_sis': 38.8000000000000}
# 21.356143810225277
# Global parameters:
#   conductor   ring degree   subtractive set size   log modulus   log sis norm       Rq size
#   v_f         v_phi         v_C                    log(v_q)      log(v_beta_sis)    v_ringelq
#   60          16            12                     64            38.8000000000000   128.0 B
# Protocol history:
#   operation   #relations         witness dimension   bundle size   log witness norm can-2   log extration norm can-2   log witness norm coeff-inf   log extration norm coeff-inf   prover comm   witness size   soundness
#               (v_ntop, v_nbot)   v_wit_rdim          v_rep         log(v_beta_wit_2)        log(v_beta_ext_2)          log(2*v_beta_wit_inf)        log(2*v_beta_ext_inf)          v_pi          v_w            -log(v_snderr)
#   init        (59, 0)            67108864/25         25            26                       26                         10                           26                             0.0000 B      1280. MB       +Infinity
#   norm        (59, 3)            67108864/25         30            27                       26                         10                           26                             48.12 KB      1536. MB       106
#   batch       (59, 1)            67108864/25         30            27                       37                         10                           34                             48.12 KB      1536. MB       106
#   split       (59, 1)            33554432/25         60            27                       37                         10                           34                             280.6 KB      1536. MB       106
#   fold        (59, 1)            33554432/25         25            35                       37                         11                           34                             280.6 KB      704.0 MB       84
#   bdecomp     (59, 1)            33554432/25         50            23                       29                         6                            29                             468.1 KB      768.0 MB       84
#   norm        (59, 4)            33554432/25         56            23                       23                         6                            23                             534.1 KB      860.2 MB       84
#   batch       (59, 1)            33554432/25         56            23                       33                         6                            29                             534.1 KB      860.2 MB       84
#   split       (59, 1)            16777216/25         112           23                       33                         6                            29                             968.1 KB      860.2 MB       84
#   fold        (59, 1)            16777216/25         25            32                       32                         7                            29                             968.1 KB      224.0 MB       83
#   bdecomp     (59, 1)            16777216/25         50            20                       24                         3                            24                             1.129 MB      192.0 MB       83
#   norm        (59, 4)            16777216/25         58            20                       20                         3                            20                             1.208 MB      222.7 MB       83
#   batch       (59, 1)            16777216/25         58            20                       38                         3                            34                             1.208 MB      222.7 MB       83
#   split       (59, 1)            8388608/25          116           20                       38                         3                            34                             1.647 MB      222.7 MB       83
#   fold        (59, 1)            8388608/25          25            29                       38                         4                            34                             1.647 MB      64.00 MB       82
#   norm        (59, 4)            8388608/25          32            29                       29                         4                            29                             1.710 MB      81.92 MB       82
#   batch       (59, 1)            8388608/25          32            29                       30                         4                            26                             1.710 MB      81.92 MB       82
#   split       (59, 1)            4194304/25          64            29                       30                         4                            26                             1.953 MB      81.92 MB       82
#   fold        (59, 1)            4194304/25          25            38                       29                         5                            26                             1.953 MB      40.00 MB       82
#   bdecomp     (59, 1)            4194304/25          50            18                       21                         2                            21                             2.136 MB      32.00 MB       82
#   norm        (59, 4)            4194304/25          59            18                       18                         2                            18                             2.223 MB      37.76 MB       82
#   batch       (59, 1)            4194304/25          59            18                       28                         2                            24                             2.223 MB      37.76 MB       82
#   split       (59, 1)            2097152/25          118           18                       28                         2                            24                             2.670 MB      37.76 MB       82
#   fold        (59, 1)            2097152/25          25            28                       28                         3                            24                             2.670 MB      12.00 MB       81
#   bdecomp     (59, 1)            2097152/25          50            17                       19                         2                            19                             2.853 MB      16.00 MB       81
#   norm        (59, 4)            2097152/25          60            17                       17                         2                            17                             2.948 MB      19.20 MB       81
#   batch       (59, 1)            2097152/25          60            17                       35                         2                            31                             2.948 MB      19.20 MB       81
#   split       (59, 1)            1048576/25          120           17                       35                         2                            31                             3.402 MB      19.20 MB       81
#   fold        (59, 1)            1048576/25          25            26                       35                         3                            31                             3.402 MB      6.000 MB       81
#   norm        (59, 4)            1048576/25          33            26                       26                         3                            26                             3.473 MB      7.920 MB       81
#   batch       (59, 1)            1048576/25          33            26                       27                         3                            24                             3.473 MB      7.920 MB       81
#   split       (59, 1)            524288/25           66            26                       27                         3                            24                             3.723 MB      7.920 MB       81
#   fold        (59, 1)            524288/25           25            35                       27                         4                            24                             3.723 MB      4.000 MB       81
#   bdecomp     (59, 1)            524288/25           50            16                       19                         2                            19                             3.906 MB      4.000 MB       81
#   norm        (59, 4)            524288/25           59            16                       16                         2                            16                             3.993 MB      4.720 MB       81
#   batch       (59, 1)            524288/25           59            16                       26                         2                            22                             3.993 MB      4.720 MB       81
#   split       (59, 1)            262144/25           118           16                       26                         2                            22                             4.440 MB      4.720 MB       81
#   fold        (59, 1)            262144/25           25            26                       25                         3                            22                             4.440 MB      1.500 MB       81
#   bdecomp     (59, 1)            262144/25           50            15                       17                         1                            17                             4.623 MB      1.000 MB       81
#   norm        (59, 4)            262144/25           61            15                       15                         1                            15                             4.726 MB      1.220 MB       81
#   batch       (59, 1)            262144/25           61            15                       33                         1                            7                              4.726 MB      1.220 MB       81
#   split       (59, 1)            131072/25           122           15                       33                         1                            7                              5.187 MB      1.220 MB       81
#   fold        (59, 1)            131072/25           25            24                       33                         2                            7                              5.187 MB      512.0 KB       80
#   finish      (59, 0)            131072/25           0             24                       24                         2                            2                              5.687 MB      0.0000 B       80

# %%
## Strategy: 
##   - Opener: init->norm->batch->split->fold
##   - Loop: bdecomp->norm->batch->split->fold

ring_param = ring_param_60_16
sis_param = gen_sis_param(ring_param = ring_param, log_beta_sis = 39.9)
print(sis_param)
rep = 25
wit_rdim = 2**32/ring_param["phi"]/rep
print(float(log(wit_rdim, 2)))
beta_inf = 1023
beta_2 = sqrt(wit_rdim * ring_param["phi"] * ring_param["fhat"]) * beta_inf
ell = 2
tdim = 2

protocol = Protocol(
    ring_param = ring_param,
    sis_param = sis_param,
    rep = rep, 
    wit_rdim = wit_rdim,  
    beta_2 = beta_2,
    beta_inf = beta_inf
)

loop_short = [("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
loop = [("bdecomp", {"ell":ell}), ("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
ops = loop_short + loop + loop + loop_short + loop + loop + loop_short + loop + loop_short + loop + loop + [("finish", {})]

for op, params in ops:
    protocol.execute(op, **params)
protocol.extract()
protocol.print()
# Out:
# {'n': 62, 'log_beta_sis': 39.9000000000000}
# 23.356143810225277
# Global parameters:
#   conductor   ring degree   subtractive set size   log modulus   log sis norm       Rq size
#   v_f         v_phi         v_C                    log(v_q)      log(v_beta_sis)    v_ringelq
#   60          16            12                     64            39.9000000000000   128.0 B
# Protocol history:
#   operation   #relations         witness dimension   bundle size   log witness norm can-2   log extration norm can-2   log witness norm coeff-inf   log extration norm coeff-inf   prover comm   witness size   soundness
#               (v_ntop, v_nbot)   v_wit_rdim          v_rep         log(v_beta_wit_2)        log(v_beta_ext_2)          log(2*v_beta_wit_inf)        log(2*v_beta_ext_inf)          v_pi          v_w            -log(v_snderr)
#   init        (62, 0)            268435456/25        25            27                       27                         10                           27                             0.0000 B      5120. MB       +Infinity
#   norm        (62, 3)            268435456/25        30            28                       27                         10                           27                             50.00 KB      6144. MB       104
#   batch       (62, 1)            268435456/25        30            28                       38                         10                           35                             50.00 KB      6144. MB       104
#   split       (62, 1)            134217728/25        60            28                       38                         10                           35                             293.8 KB      6144. MB       104
#   fold        (62, 1)            134217728/25        25            36                       38                         11                           35                             293.8 KB      2816. MB       84
#   bdecomp     (62, 1)            134217728/25        50            24                       30                         6                            30                             490.6 KB      3072. MB       84
#   norm        (62, 4)            134217728/25        57            24                       24                         6                            24                             567.1 KB      3502. MB       84
#   batch       (62, 1)            134217728/25        57            24                       34                         6                            30                             567.1 KB      3502. MB       84
#   split       (62, 1)            67108864/25         114           24                       34                         6                            30                             1.006 MB      3502. MB       84
#   fold        (62, 1)            67108864/25         25            33                       33                         7                            30                             1.006 MB      896.0 MB       83
#   bdecomp     (62, 1)            67108864/25         50            21                       25                         3                            25                             1.198 MB      768.0 MB       83
#   norm        (62, 4)            67108864/25         59            21                       21                         3                            21                             1.289 MB      906.2 MB       83
#   batch       (62, 1)            67108864/25         59            21                       39                         3                            35                             1.289 MB      906.2 MB       83
#   split       (62, 1)            33554432/25         118           21                       39                         3                            35                             1.757 MB      906.2 MB       83
#   fold        (62, 1)            33554432/25         25            30                       39                         4                            35                             1.757 MB      256.0 MB       82
#   norm        (62, 4)            33554432/25         32            30                       30                         4                            30                             1.823 MB      327.7 MB       82
#   batch       (62, 1)            33554432/25         32            30                       31                         4                            27                             1.823 MB      327.7 MB       82
#   split       (62, 1)            16777216/25         64            30                       31                         4                            27                             2.077 MB      327.7 MB       82
#   fold        (62, 1)            16777216/25         25            39                       30                         5                            27                             2.077 MB      160.0 MB       82
#   bdecomp     (62, 1)            16777216/25         50            19                       22                         2                            22                             2.269 MB      128.0 MB       82
#   norm        (62, 4)            16777216/25         60            19                       19                         2                            19                             2.368 MB      153.6 MB       82
#   batch       (62, 1)            16777216/25         60            19                       29                         2                            25                             2.368 MB      153.6 MB       82
#   split       (62, 1)            8388608/25          120           19                       29                         2                            25                             2.844 MB      153.6 MB       82
#   fold        (62, 1)            8388608/25          25            29                       29                         3                            25                             2.844 MB      48.00 MB       81
#   bdecomp     (62, 1)            8388608/25          50            18                       20                         2                            20                             3.036 MB      64.00 MB       81
#   norm        (62, 4)            8388608/25          61            18                       18                         2                            18                             3.143 MB      78.08 MB       81
#   batch       (62, 1)            8388608/25          61            18                       36                         2                            32                             3.143 MB      78.08 MB       81
#   split       (62, 1)            4194304/25          122           18                       36                         2                            32                             3.627 MB      78.08 MB       81
#   fold        (62, 1)            4194304/25          25            27                       36                         3                            32                             3.627 MB      24.00 MB       81
#   norm        (62, 4)            4194304/25          33            27                       27                         3                            27                             3.701 MB      31.68 MB       81
#   batch       (62, 1)            4194304/25          33            27                       28                         3                            25                             3.701 MB      31.68 MB       81
#   split       (62, 1)            2097152/25          66            27                       28                         3                            25                             3.963 MB      31.68 MB       81
#   fold        (62, 1)            2097152/25          25            36                       28                         4                            25                             3.963 MB      16.00 MB       81
#   bdecomp     (62, 1)            2097152/25          50            17                       20                         2                            20                             4.155 MB      16.00 MB       81
#   norm        (62, 4)            2097152/25          60            17                       17                         2                            17                             4.254 MB      19.20 MB       81
#   batch       (62, 1)            2097152/25          60            17                       36                         2                            32                             4.254 MB      19.20 MB       81
#   split       (62, 1)            1048576/25          120           17                       36                         2                            32                             4.730 MB      19.20 MB       81
#   fold        (62, 1)            1048576/25          25            27                       35                         3                            32                             4.730 MB      6.000 MB       81
#   norm        (62, 4)            1048576/25          33            27                       27                         3                            27                             4.803 MB      7.920 MB       81
#   batch       (62, 1)            1048576/25          33            27                       27                         3                            24                             4.803 MB      7.920 MB       81
#   split       (62, 1)            524288/25           66            27                       27                         3                            24                             5.065 MB      7.920 MB       81
#   fold        (62, 1)            524288/25           25            35                       27                         4                            24                             5.065 MB      4.000 MB       80
#   bdecomp     (62, 1)            524288/25           50            16                       19                         2                            19                             5.258 MB      4.000 MB       80
#   norm        (62, 4)            524288/25           59            16                       16                         2                            16                             5.348 MB      4.720 MB       80
#   batch       (62, 1)            524288/25           59            16                       26                         2                            22                             5.348 MB      4.720 MB       80
#   split       (62, 1)            262144/25           118           16                       26                         2                            22                             5.817 MB      4.720 MB       80
#   fold        (62, 1)            262144/25           25            26                       25                         3                            22                             5.817 MB      1.500 MB       80
#   bdecomp     (62, 1)            262144/25           50            15                       17                         1                            17                             6.009 MB      1.000 MB       80
#   norm        (62, 4)            262144/25           61            15                       15                         1                            15                             6.116 MB      1.220 MB       80
#   batch       (62, 1)            262144/25           61            15                       33                         1                            7                              6.116 MB      1.220 MB       80
#   split       (62, 1)            131072/25           122           15                       33                         1                            7                              6.600 MB      1.220 MB       80
#   fold        (62, 1)            131072/25           25            24                       33                         2                            7                              6.600 MB      512.0 KB       80
#   finish      (62, 0)            131072/25           0             24                       24                         2                            2                              7.100 MB      0.0000 B       80

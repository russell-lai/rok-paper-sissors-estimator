# %%
from symbolic_variables import *
from gen_params import gen_ring_param, gen_sis_param, gen_sis_param_aggresive
from ring_params import *
from protocol import Protocol

# %%
## Strategy: 
## small rings
##   - Opener: init->norm->batch->split->fold
##   - Loop: bdecomp->norm->batch->split->fold

ring_param = ring_param_60_16
sis_param = gen_sis_param(ring_param = ring_param, log_beta_sis = 39.9)
print(sis_param)
rep = 25
wit_rdim = 2**32/ring_param["phi"]/rep
print(float(log(wit_rdim, 2)))
beta_inf = 2^19
beta_2 = sqrt(wit_rdim * ring_param["phi"] * ring_param["fhat"]) * beta_inf
ell = 2
tdim = 2

protocol = Protocol(
    ring_param = ring_param,
    sis_param = sis_param,
    rep = rep, 
    wit_rdim = wit_rdim,  
    beta_2 = beta_2,
    beta_inf = beta_inf
)

loop_short = [("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
loop = [("bdecomp", {"ell":ell}), ("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
ops = loop + loop + loop + loop_short + loop + loop + loop_short + loop + loop_short + loop + loop + [("finish", {})]

for op, params in ops:
    protocol.execute(op, **params)
protocol.extract()
protocol.print()
# Out:
# {'n': 62, 'log_beta_sis': 39.9000000000000}
# 23.356143810225277
# Global parameters:
#   conductor   ring degree   subtractive set size   log modulus   log sis norm       Rq size
#   v_f         v_phi         v_C                    log(v_q)      log(v_beta_sis)    v_ringelq
#   60          16            12                     64            39.9000000000000   128.0 B
# Protocol history:
#   operation   #relations         witness dimension   bundle size   log witness norm can-2   log extration norm can-2   log witness norm coeff-inf   log extration norm coeff-inf   prover comm   witness size   soundness
#               (v_ntop, v_nbot)   v_wit_rdim          v_rep         log(v_beta_wit_2)        log(v_beta_ext_2)          log(2*v_beta_wit_inf)        log(2*v_beta_ext_inf)          v_pi          v_w            -log(v_snderr)
#   init        (62, 0)            268435456/25        25            36                       38                         20                           38                             0.0000 B      10240. MB      +Infinity
#   bdecomp     (62, 0)            268435456/25        50            28                       38                         10                           38                             193.8 KB      10240. MB      +Infinity
#   norm        (62, 3)            268435456/25        55            29                       28                         10                           28                             253.1 KB      11260. MB      104
#   batch       (62, 1)            268435456/25        55            29                       38                         10                           34                             253.1 KB      11260. MB      104
#   split       (62, 1)            134217728/25        110           29                       38                         10                           34                             700.0 KB      11260. MB      104
#   fold        (62, 1)            134217728/25        25            38                       37                         11                           34                             700.0 KB      2816. MB       83
#   bdecomp     (62, 1)            134217728/25        50            23                       29                         5                            29                             896.9 KB      2560. MB       83
#   norm        (62, 4)            134217728/25        57            24                       23                         5                            23                             973.4 KB      2918. MB       83
#   batch       (62, 1)            134217728/25        57            24                       33                         5                            29                             973.4 KB      2918. MB       83
#   split       (62, 1)            67108864/25         114           24                       33                         5                            29                             1.403 MB      2918. MB       83
#   fold        (62, 1)            67108864/25         25            33                       33                         6                            29                             1.403 MB      768.0 MB       82
#   bdecomp     (62, 1)            67108864/25         50            21                       24                         3                            24                             1.595 MB      768.0 MB       82
#   norm        (62, 4)            67108864/25         59            21                       21                         3                            21                             1.686 MB      906.2 MB       82
#   batch       (62, 1)            67108864/25         59            21                       39                         3                            35                             1.686 MB      906.2 MB       82
#   split       (62, 1)            33554432/25         118           21                       39                         3                            35                             2.154 MB      906.2 MB       82
#   fold        (62, 1)            33554432/25         25            30                       39                         4                            35                             2.154 MB      256.0 MB       82
#   norm        (62, 4)            33554432/25         33            30                       30                         4                            30                             2.228 MB      337.9 MB       82
#   batch       (62, 1)            33554432/25         33            30                       31                         4                            27                             2.228 MB      337.9 MB       82
#   split       (62, 1)            16777216/25         66            30                       31                         4                            27                             2.490 MB      337.9 MB       82
#   fold        (62, 1)            16777216/25         25            38                       30                         5                            27                             2.490 MB      160.0 MB       81
#   bdecomp     (62, 1)            16777216/25         50            19                       22                         2                            22                             2.682 MB      128.0 MB       81
#   norm        (62, 4)            16777216/25         60            19                       19                         2                            19                             2.781 MB      153.6 MB       81
#   batch       (62, 1)            16777216/25         60            19                       29                         2                            25                             2.781 MB      153.6 MB       81
#   split       (62, 1)            8388608/25          120           19                       29                         2                            25                             3.257 MB      153.6 MB       81
#   fold        (62, 1)            8388608/25          25            29                       29                         3                            25                             3.257 MB      48.00 MB       81
#   bdecomp     (62, 1)            8388608/25          50            18                       20                         2                            20                             3.449 MB      64.00 MB       81
#   norm        (62, 4)            8388608/25          61            18                       18                         2                            18                             3.556 MB      78.08 MB       81
#   batch       (62, 1)            8388608/25          61            18                       36                         2                            32                             3.556 MB      78.08 MB       81
#   split       (62, 1)            4194304/25          122           18                       36                         2                            32                             4.040 MB      78.08 MB       81
#   fold        (62, 1)            4194304/25          25            27                       36                         3                            32                             4.040 MB      24.00 MB       81
#   norm        (62, 4)            4194304/25          33            27                       27                         3                            27                             4.114 MB      31.68 MB       81
#   batch       (62, 1)            4194304/25          33            27                       28                         3                            25                             4.114 MB      31.68 MB       81
#   split       (62, 1)            2097152/25          66            27                       28                         3                            25                             4.375 MB      31.68 MB       81
#   fold        (62, 1)            2097152/25          25            36                       28                         4                            25                             4.375 MB      16.00 MB       81
#   bdecomp     (62, 1)            2097152/25          50            17                       20                         2                            20                             4.568 MB      16.00 MB       81
#   norm        (62, 4)            2097152/25          60            17                       17                         2                            17                             4.667 MB      19.20 MB       81
#   batch       (62, 1)            2097152/25          60            17                       36                         2                            32                             4.667 MB      19.20 MB       81
#   split       (62, 1)            1048576/25          120           17                       36                         2                            32                             5.143 MB      19.20 MB       81
#   fold        (62, 1)            1048576/25          25            27                       35                         3                            32                             5.143 MB      6.000 MB       80
#   norm        (62, 4)            1048576/25          33            27                       27                         3                            27                             5.216 MB      7.920 MB       80
#   batch       (62, 1)            1048576/25          33            27                       27                         3                            24                             5.216 MB      7.920 MB       80
#   split       (62, 1)            524288/25           66            27                       27                         3                            24                             5.478 MB      7.920 MB       80
#   fold        (62, 1)            524288/25           25            35                       27                         4                            24                             5.478 MB      4.000 MB       80
#   bdecomp     (62, 1)            524288/25           50            16                       19                         2                            19                             5.670 MB      4.000 MB       80
#   norm        (62, 4)            524288/25           59            16                       16                         2                            16                             5.761 MB      4.720 MB       80
#   batch       (62, 1)            524288/25           59            16                       26                         2                            22                             5.761 MB      4.720 MB       80
#   split       (62, 1)            262144/25           118           16                       26                         2                            22                             6.229 MB      4.720 MB       80
#   fold        (62, 1)            262144/25           25            26                       25                         3                            22                             6.229 MB      1.500 MB       80
#   bdecomp     (62, 1)            262144/25           50            15                       17                         1                            17                             6.422 MB      1.000 MB       80
#   norm        (62, 4)            262144/25           61            15                       15                         1                            15                             6.528 MB      1.220 MB       80
#   batch       (62, 1)            262144/25           61            15                       33                         1                            7                              6.528 MB      1.220 MB       80
#   split       (62, 1)            131072/25           122           15                       33                         1                            7                              7.012 MB      1.220 MB       80
#   fold        (62, 1)            131072/25           25            24                       33                         2                            7                              7.012 MB      512.0 KB       80
#   finish      (62, 0)            131072/25           0             24                       24                         2                            2                              7.512 MB      0.0000 B       80

# %%
## Strategy: 
## small rings - hp
##   - Opener: init->norm->batch->split->fold
##   - Loop: bdecomp->norm->batch->split->fold

ring_param = ring_param_60_16
sis_param = gen_sis_param(ring_param = ring_param, log_beta_sis = 39.9)
print(sis_param)
rep = 25
wit_rdim = 2**32/ring_param["phi"]/rep
print(float(log(wit_rdim, 2)))
beta_inf = 2^19
beta_2 = sqrt(wit_rdim * ring_param["phi"] * ring_param["fhat"]) * beta_inf
ell = 2
tdim = 2

protocol = Protocol(
    ring_param = ring_param,
    sis_param = sis_param,
    rep = rep, 
    wit_rdim = wit_rdim,  
    beta_2 = beta_2,
    beta_inf = beta_inf
)

loop_short = [("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
loop = [("bdecomp", {"ell":ell}), ("norm-hp", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
ops = loop + loop + loop + loop_short + loop + loop_short + loop + loop_short + loop + loop_short + loop + [("finish", {})]

for op, params in ops:
    protocol.execute(op, **params)
protocol.extract()
protocol.print()
# Out:
# {'n': 62, 'log_beta_sis': 39.9000000000000}
# 23.356143810225277
# Global parameters:
#   conductor   ring degree   subtractive set size   log modulus   log sis norm       Rq size
#   v_f         v_phi         v_C                    log(v_q)      log(v_beta_sis)    v_ringelq
#   60          16            12                     64            39.9000000000000   128.0 B
# Protocol history:
#   operation   #relations         witness dimension   bundle size   log witness norm can-2   log extration norm can-2   log witness norm coeff-inf   log extration norm coeff-inf   prover comm   witness size   soundness
#               (v_ntop, v_nbot)   v_wit_rdim          v_rep         log(v_beta_wit_2)        log(v_beta_ext_2)          log(2*v_beta_wit_inf)        log(2*v_beta_ext_inf)          v_pi          v_w            -log(v_snderr)
#   init        (62, 0)            268435456/25        25            36                       38                         20                           38                             0.0000 B      10240. MB      +Infinity
#   bdecomp     (62, 0)            268435456/25        50            28                       38                         10                           38                             193.8 KB      10240. MB      +Infinity
#   norm-hp     (62, 1)            268435456/25        55            28                       28                         10                           28                             493.8 KB      11260. MB      104
#   batch       (62, 1)            268435456/25        55            28                       38                         10                           34                             493.8 KB      11260. MB      104
#   split       (62, 1)            134217728/25        110           28                       38                         10                           34                             940.6 KB      11260. MB      104
#   fold        (62, 1)            134217728/25        25            38                       37                         11                           34                             940.6 KB      2816. MB       83
#   bdecomp     (62, 1)            134217728/25        50            23                       29                         5                            29                             1.111 MB      2560. MB       83
#   norm-hp     (62, 2)            134217728/25        57            23                       23                         5                            23                             1.392 MB      2918. MB       83
#   batch       (62, 1)            134217728/25        57            23                       33                         5                            29                             1.392 MB      2918. MB       83
#   split       (62, 1)            67108864/25         114           23                       33                         5                            29                             1.844 MB      2918. MB       83
#   fold        (62, 1)            67108864/25         25            33                       33                         6                            29                             1.844 MB      768.0 MB       82
#   bdecomp     (62, 1)            67108864/25         50            21                       24                         3                            24                             2.036 MB      768.0 MB       82
#   norm-hp     (62, 2)            67108864/25         59            21                       21                         3                            21                             2.305 MB      906.2 MB       82
#   batch       (62, 1)            67108864/25         59            21                       39                         3                            35                             2.305 MB      906.2 MB       82
#   split       (62, 1)            33554432/25         118           21                       39                         3                            35                             2.773 MB      906.2 MB       82
#   fold        (62, 1)            33554432/25         25            30                       38                         4                            35                             2.773 MB      256.0 MB       82
#   norm        (62, 4)            33554432/25         33            30                       30                         4                            30                             2.846 MB      337.9 MB       82
#   batch       (62, 1)            33554432/25         33            30                       31                         4                            27                             2.846 MB      337.9 MB       82
#   split       (62, 1)            16777216/25         66            30                       31                         4                            27                             3.108 MB      337.9 MB       82
#   fold        (62, 1)            16777216/25         25            38                       30                         5                            27                             3.108 MB      160.0 MB       81
#   bdecomp     (62, 1)            16777216/25         50            19                       22                         2                            22                             3.301 MB      128.0 MB       81
#   norm-hp     (62, 2)            16777216/25         60            19                       19                         2                            19                             3.545 MB      153.6 MB       81
#   batch       (62, 1)            16777216/25         60            19                       37                         2                            33                             3.545 MB      153.6 MB       81
#   split       (62, 1)            8388608/25          120           19                       37                         2                            33                             4.021 MB      153.6 MB       81
#   fold        (62, 1)            8388608/25          25            28                       37                         3                            33                             4.021 MB      48.00 MB       81
#   norm        (62, 4)            8388608/25          33            28                       28                         3                            28                             4.094 MB      63.36 MB       81
#   batch       (62, 1)            8388608/25          33            28                       29                         3                            25                             4.094 MB      63.36 MB       81
#   split       (62, 1)            4194304/25          66            28                       29                         3                            25                             4.356 MB      63.36 MB       81
#   fold        (62, 1)            4194304/25          25            37                       28                         4                            25                             4.356 MB      32.00 MB       81
#   bdecomp     (62, 1)            4194304/25          50            18                       20                         2                            20                             4.548 MB      32.00 MB       81
#   norm-hp     (62, 2)            4194304/25          61            18                       18                         2                            18                             4.768 MB      39.04 MB       81
#   batch       (62, 1)            4194304/25          61            18                       36                         2                            32                             4.768 MB      39.04 MB       81
#   split       (62, 1)            2097152/25          122           18                       36                         2                            32                             5.252 MB      39.04 MB       81
#   fold        (62, 1)            2097152/25          25            27                       35                         3                            32                             5.252 MB      12.00 MB       81
#   norm        (62, 4)            2097152/25          33            27                       27                         3                            27                             5.326 MB      15.84 MB       81
#   batch       (62, 1)            2097152/25          33            27                       28                         3                            24                             5.326 MB      15.84 MB       81
#   split       (62, 1)            1048576/25          66            27                       28                         3                            24                             5.588 MB      15.84 MB       81
#   fold        (62, 1)            1048576/25          25            35                       27                         4                            24                             5.588 MB      8.000 MB       81
#   bdecomp     (62, 1)            1048576/25          50            17                       19                         2                            19                             5.780 MB      8.000 MB       81
#   norm-hp     (62, 2)            1048576/25          60            17                       17                         2                            17                             5.975 MB      9.600 MB       81
#   batch       (62, 1)            1048576/25          60            17                       35                         2                            31                             5.975 MB      9.600 MB       81
#   split       (62, 1)            524288/25           120           17                       35                         2                            31                             6.451 MB      9.600 MB       81
#   fold        (62, 1)            524288/25           25            26                       34                         3                            31                             6.451 MB      3.000 MB       80
#   norm        (62, 4)            524288/25           33            26                       26                         3                            26                             6.525 MB      3.960 MB       80
#   batch       (62, 1)            524288/25           33            26                       27                         3                            23                             6.525 MB      3.960 MB       80
#   split       (62, 1)            262144/25           66            26                       27                         3                            23                             6.787 MB      3.960 MB       80
#   fold        (62, 1)            262144/25           25            34                       26                         4                            23                             6.787 MB      2.000 MB       80
#   bdecomp     (62, 1)            262144/25           50            16                       18                         2                            18                             6.979 MB      2.000 MB       80
#   norm-hp     (62, 2)            262144/25           59            16                       16                         2                            16                             7.150 MB      2.360 MB       80
#   batch       (62, 1)            262144/25           59            16                       34                         2                            8                              7.150 MB      2.360 MB       80
#   split       (62, 1)            131072/25           118           16                       34                         2                            8                              7.618 MB      2.360 MB       80
#   fold        (62, 1)            131072/25           25            25                       33                         3                            8                              7.618 MB      768.0 KB       80
#   finish      (62, 0)            131072/25           0             25                       25                         3                            3                              8.368 MB      0.0000 B       80

# %%
## Strategy: 
## BIG RINGS 
##   - Opener: init->norm->batch->split->fold
##   - Loop: bdecomp->norm->batch->split->fold

ring_param = ring_param_2520_576

sis_param = gen_sis_param(ring_param = ring_param, log_beta_sis = 52)
print(sis_param)
rep = 11
wit_rdim = 2**32/ring_param["phi"]/rep
print(float(log(wit_rdim, 2)))
beta_inf = 2^19
beta_2 = sqrt(wit_rdim * ring_param["phi"] * ring_param["fhat"]) * beta_inf
ell = 3
tdim = 2

protocol = Protocol(
    ring_param = ring_param,
    sis_param = sis_param,
    rep = rep, 
    wit_rdim = wit_rdim,  
    beta_2 = beta_2,
    beta_inf = beta_inf
)

loop_short = [("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
loop = [("bdecomp", {"ell":ell}), ("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
# ops = [("bdecomp", {"ell":3})] + loop_short + loop + loop + loop + loop + loop + loop + loop + loop + [("finish", {})]
ops = loop + loop_short + loop + loop_short + loop + loop_short + loop_short + loop + loop + [("finish", {})]

for op, params in ops:
    protocol.execute(op, **params)
protocol.extract()
protocol.print()
# Out:
# {'n': 3, 'log_beta_sis': 52}
# 19.37064337992039
# Global parameters:
#   conductor   ring degree   subtractive set size   log modulus   log sis norm      Rq size
#   v_f         v_phi         v_C                    log(v_q)      log(v_beta_sis)   v_ringelq
#   2520        576           360                    64            52                4.500 KB
# Protocol history:
#   operation   #relations         witness dimension   bundle size   log witness norm can-2   log extration norm can-2   log witness norm coeff-inf   log extration norm coeff-inf   prover comm   witness size   soundness
#               (v_ntop, v_nbot)   v_wit_rdim          v_rep         log(v_beta_wit_2)        log(v_beta_ext_2)          log(2*v_beta_wit_inf)        log(2*v_beta_ext_inf)          v_pi          v_w            -log(v_snderr)
#   init        (3, 0)             67108864/99         11            39                       41                         20                           41                             0.0000 B      10240. MB      +Infinity
#   bdecomp     (3, 0)             67108864/99         33            28                       41                         6                            41                             297.0 KB      9216. MB       +Infinity
#   norm        (3, 3)             67108864/99         39            28                       28                         6                            28                             904.5 KB      10890. MB      108
#   batch       (3, 1)             67108864/99         39            28                       50                         6                            46                             904.5 KB      10890. MB      108
#   split       (3, 1)             33554432/99         78            28                       50                         6                            46                             1.912 MB      10890. MB      108
#   fold        (3, 1)             33554432/99         11            36                       50                         7                            46                             1.912 MB      1792. MB       88
#   norm        (3, 4)             33554432/99         17            36                       36                         7                            36                             2.241 MB      2769. MB       88
#   batch       (3, 1)             33554432/99         17            36                       43                         7                            40                             2.241 MB      2769. MB       88
#   split       (3, 1)             16777216/99         34            36                       43                         7                            40                             2.689 MB      2769. MB       88
#   fold        (3, 1)             16777216/99         11            43                       42                         8                            40                             2.689 MB      1024. MB       87
#   bdecomp     (3, 1)             16777216/99         33            23                       30                         3                            30                             3.076 MB      1152. MB       87
#   norm        (3, 4)             16777216/99         43            24                       23                         3                            23                             3.819 MB      1501. MB       87
#   batch       (3, 1)             16777216/99         43            24                       46                         3                            42                             3.819 MB      1501. MB       87
#   split       (3, 1)             8388608/99          86            24                       46                         3                            42                             4.953 MB      1501. MB       87
#   fold        (3, 1)             8388608/99          11            32                       45                         4                            42                             4.953 MB      256.0 MB       86
#   norm        (3, 4)             8388608/99          19            32                       32                         4                            32                             5.344 MB      442.2 MB       86
#   batch       (3, 1)             8388608/99          19            32                       39                         4                            36                             5.344 MB      442.2 MB       86
#   split       (3, 1)             4194304/99          38            32                       39                         4                            36                             5.845 MB      442.2 MB       86
#   fold        (3, 1)             4194304/99          11            39                       39                         5                            36                             5.845 MB      160.0 MB       86
#   bdecomp     (3, 1)             4194304/99          33            21                       26                         2                            26                             6.231 MB      192.0 MB       86
#   norm        (3, 4)             4194304/99          45            22                       21                         2                            21                             7.036 MB      261.8 MB       86
#   batch       (3, 1)             4194304/99          45            22                       44                         2                            40                             7.036 MB      261.8 MB       86
#   split       (3, 1)             2097152/99          90            22                       44                         2                            40                             8.222 MB      261.8 MB       86
#   fold        (3, 1)             2097152/99          11            30                       43                         3                            40                             8.222 MB      48.00 MB       86
#   norm        (3, 4)             2097152/99          20            30                       30                         3                            30                             8.644 MB      87.27 MB       86
#   batch       (3, 1)             2097152/99          20            30                       50                         3                            47                             8.644 MB      87.27 MB       86
#   split       (3, 1)             1048576/99          40            30                       50                         3                            47                             9.171 MB      87.27 MB       86
#   fold        (3, 1)             1048576/99          11            37                       50                         4                            47                             9.171 MB      32.00 MB       85
#   norm        (3, 4)             1048576/99          18            37                       37                         4                            37                             9.532 MB      52.36 MB       85
#   batch       (3, 1)             1048576/99          18            37                       38                         4                            35                             9.532 MB      52.36 MB       85
#   split       (3, 1)             524288/99           36            37                       38                         4                            35                             10.01 MB      52.36 MB       85
#   fold        (3, 1)             524288/99           11            44                       37                         5                            35                             10.01 MB      20.00 MB       85
#   bdecomp     (3, 1)             524288/99           33            20                       24                         2                            24                             10.39 MB      24.00 MB       85
#   norm        (3, 4)             524288/99           44            20                       20                         2                            20                             11.17 MB      32.00 MB       85
#   batch       (3, 1)             524288/99           44            20                       37                         2                            33                             11.17 MB      32.00 MB       85
#   split       (3, 1)             262144/99           88            20                       37                         2                            33                             12.33 MB      32.00 MB       85
#   fold        (3, 1)             262144/99           11            28                       36                         3                            33                             12.33 MB      6.000 MB       85
#   bdecomp     (3, 1)             262144/99           33            19                       23                         1                            23                             12.71 MB      6.000 MB       85
#   norm        (3, 4)             262144/99           46            19                       19                         1                            19                             13.55 MB      8.364 MB       85
#   batch       (3, 1)             262144/99           46            19                       41                         1                            12                             13.55 MB      8.364 MB       85
#   split       (3, 1)             131072/99           92            19                       41                         1                            12                             14.76 MB      8.364 MB       85
#   fold        (3, 1)             131072/99           11            27                       41                         2                            12                             14.76 MB      2.000 MB       85
#   finish      (3, 0)             131072/99           0             27                       27                         2                            2                              16.76 MB      0.0000 B       85

# %%
## Strategy: 
## BIG RINGS - HP
##   - Opener: init->norm->batch->split->fold
##   - Loop: bdecomp->norm->batch->split->fold

ring_param = ring_param_2520_576

sis_param = gen_sis_param(ring_param = ring_param, log_beta_sis = 52)
print(sis_param)
rep = 11
wit_rdim = 2**32/ring_param["phi"]/rep
print(float(log(wit_rdim, 2)))
beta_inf = 2^19
beta_2 = sqrt(wit_rdim * ring_param["phi"] * ring_param["fhat"]) * beta_inf
ell = 3
tdim = 2

protocol = Protocol(
    ring_param = ring_param,
    sis_param = sis_param,
    rep = rep, 
    wit_rdim = wit_rdim,  
    beta_2 = beta_2,
    beta_inf = beta_inf
)

loop_short = [("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
loop = [("bdecomp", {"ell":ell}), ("norm-hp", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
# ops = [("bdecomp", {"ell":3})] + loop_short + loop + loop + loop + loop + loop + loop + loop + loop + [("finish", {})]
ops = loop + loop_short + loop + loop_short + loop + loop_short + loop_short + loop + [("finish", {})]

for op, params in ops:
    protocol.execute(op, **params)
protocol.extract()
protocol.print()
# Out:
# {'n': 3, 'log_beta_sis': 52}
# 19.37064337992039
# Global parameters:
#   conductor   ring degree   subtractive set size   log modulus   log sis norm      Rq size
#   v_f         v_phi         v_C                    log(v_q)      log(v_beta_sis)   v_ringelq
#   2520        576           360                    64            52                4.500 KB
# Protocol history:
#   operation   #relations         witness dimension   bundle size   log witness norm can-2   log extration norm can-2   log witness norm coeff-inf   log extration norm coeff-inf   prover comm   witness size   soundness
#               (v_ntop, v_nbot)   v_wit_rdim          v_rep         log(v_beta_wit_2)        log(v_beta_ext_2)          log(2*v_beta_wit_inf)        log(2*v_beta_ext_inf)          v_pi          v_w            -log(v_snderr)
#   init        (3, 0)             67108864/99         11            39                       41                         20                           41                             0.0000 B      10240. MB      +Infinity
#   bdecomp     (3, 0)             67108864/99         33            28                       41                         6                            41                             297.0 KB      9216. MB       +Infinity
#   norm-hp     (3, 1)             67108864/99         39            28                       28                         6                            28                             6.091 MB      10890. MB      108
#   batch       (3, 1)             67108864/99         39            28                       50                         6                            46                             6.091 MB      10890. MB      108
#   split       (3, 1)             33554432/99         78            28                       50                         6                            46                             7.119 MB      10890. MB      108
#   fold        (3, 1)             33554432/99         11            36                       49                         7                            46                             7.119 MB      1792. MB       88
#   norm        (3, 4)             33554432/99         17            36                       36                         7                            36                             7.449 MB      2769. MB       88
#   batch       (3, 1)             33554432/99         17            36                       43                         7                            40                             7.449 MB      2769. MB       88
#   split       (3, 1)             16777216/99         34            36                       43                         7                            40                             7.897 MB      2769. MB       88
#   fold        (3, 1)             16777216/99         11            43                       42                         8                            40                             7.897 MB      1024. MB       87
#   bdecomp     (3, 1)             16777216/99         33            23                       30                         3                            30                             8.284 MB      1152. MB       87
#   norm-hp     (3, 2)             16777216/99         43            23                       23                         3                            23                             13.50 MB      1501. MB       87
#   batch       (3, 1)             16777216/99         43            23                       45                         3                            42                             13.50 MB      1501. MB       87
#   split       (3, 1)             8388608/99          86            23                       45                         3                            42                             14.64 MB      1501. MB       87
#   fold        (3, 1)             8388608/99          11            32                       45                         4                            42                             14.64 MB      256.0 MB       86
#   norm        (3, 4)             8388608/99          19            32                       32                         4                            32                             15.03 MB      442.2 MB       86
#   batch       (3, 1)             8388608/99          19            32                       39                         4                            36                             15.03 MB      442.2 MB       86
#   split       (3, 1)             4194304/99          38            32                       39                         4                            36                             15.53 MB      442.2 MB       86
#   fold        (3, 1)             4194304/99          11            39                       39                         5                            36                             15.53 MB      160.0 MB       86
#   bdecomp     (3, 1)             4194304/99          33            21                       26                         2                            26                             15.92 MB      192.0 MB       86
#   norm-hp     (3, 2)             4194304/99          45            21                       21                         2                            21                             20.56 MB      261.8 MB       86
#   batch       (3, 1)             4194304/99          45            21                       44                         2                            40                             20.56 MB      261.8 MB       86
#   split       (3, 1)             2097152/99          90            21                       44                         2                            40                             21.74 MB      261.8 MB       86
#   fold        (3, 1)             2097152/99          11            30                       43                         3                            40                             21.74 MB      48.00 MB       86
#   norm        (3, 4)             2097152/99          20            30                       30                         3                            30                             22.17 MB      87.27 MB       86
#   batch       (3, 1)             2097152/99          20            30                       50                         3                            47                             22.17 MB      87.27 MB       86
#   split       (3, 1)             1048576/99          40            30                       50                         3                            47                             22.69 MB      87.27 MB       86
#   fold        (3, 1)             1048576/99          11            37                       50                         4                            47                             22.69 MB      32.00 MB       85
#   norm        (3, 4)             1048576/99          18            37                       37                         4                            37                             23.05 MB      52.36 MB       85
#   batch       (3, 1)             1048576/99          18            37                       38                         4                            35                             23.05 MB      52.36 MB       85
#   split       (3, 1)             524288/99           36            37                       38                         4                            35                             23.53 MB      52.36 MB       85
#   fold        (3, 1)             524288/99           11            44                       37                         5                            35                             23.53 MB      20.00 MB       85
#   bdecomp     (3, 1)             524288/99           33            20                       24                         2                            24                             23.92 MB      24.00 MB       85
#   norm-hp     (3, 2)             524288/99           44            20                       20                         2                            20                             27.69 MB      32.00 MB       85
#   batch       (3, 1)             524288/99           44            20                       42                         2                            13                             27.69 MB      32.00 MB       85
#   split       (3, 1)             262144/99           88            20                       42                         2                            13                             28.85 MB      32.00 MB       85
#   fold        (3, 1)             262144/99           11            28                       42                         3                            13                             28.85 MB      6.000 MB       85
#   finish      (3, 0)             262144/99           0             28                       28                         3                            3                              34.85 MB      0.0000 B       85

# %%
## Strategy: 
## BIG RINGS - HP -tensor
##   - Opener: init->norm->batch->split->fold
##   - Loop: bdecomp->norm->batch->split->fold

ring_param = ring_param_2520_576

sis_param = gen_sis_param(ring_param = ring_param, log_beta_sis = 52)
print(sis_param)
rep = 11
wit_rdim = 2**32/ring_param["phi"]/rep
print(float(log(wit_rdim, 2)))
beta_inf = 2^19
beta_2 = sqrt(wit_rdim * ring_param["phi"] * ring_param["fhat"]) * beta_inf
ell = 3
tdim = 2

protocol = Protocol(
    ring_param = ring_param,
    sis_param = sis_param,
    rep = rep, 
    wit_rdim = wit_rdim,  
    beta_2 = beta_2,
    beta_inf = beta_inf
)

loop_short = [("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
loop = [("bdecomp", {"ell":ell}), ("norm-hp-tensor", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
# ops = [("bdecomp", {"ell":3})] + loop_short + loop + loop + loop + loop + loop + loop + loop + loop + [("finish", {})]
ops = loop + loop_short + loop + loop_short + loop + loop_short + loop_short + loop + loop + [("finish", {})]

for op, params in ops:
    protocol.execute(op, **params)
protocol.extract()
protocol.print()
# Out:
# {'n': 3, 'log_beta_sis': 52}
# 19.37064337992039
# Global parameters:
#   conductor   ring degree   subtractive set size   log modulus   log sis norm      Rq size
#   v_f         v_phi         v_C                    log(v_q)      log(v_beta_sis)   v_ringelq
#   2520        576           360                    64            52                4.500 KB
# Protocol history:
#   operation        #relations         witness dimension   bundle size   log witness norm can-2   log extration norm can-2   log witness norm coeff-inf   log extration norm coeff-inf   prover comm   witness size   soundness
#                    (v_ntop, v_nbot)   v_wit_rdim          v_rep         log(v_beta_wit_2)        log(v_beta_ext_2)          log(2*v_beta_wit_inf)        log(2*v_beta_ext_inf)          v_pi          v_w            -log(v_snderr)
#   init             (3, 0)             67108864/99         11            39                       41                         20                           41                             0.0000 B      10240. MB      +Infinity
#   bdecomp          (3, 0)             67108864/99         33            28                       41                         6                            41                             297.0 KB      9216. MB       +Infinity
#   norm-hp-tensor   (3, 1)             67108864/99         39            28                       28                         6                            28                             312.0 KB      10890. MB      108
#   batch            (3, 1)             67108864/99         39            28                       50                         6                            46                             312.0 KB      10890. MB      108
#   split            (3, 1)             33554432/99         78            28                       50                         6                            46                             1.333 MB      10890. MB      108
#   fold             (3, 1)             33554432/99         11            36                       49                         7                            46                             1.333 MB      1792. MB       88
#   norm             (3, 4)             33554432/99         17            36                       36                         7                            36                             1.663 MB      2769. MB       88
#   batch            (3, 1)             33554432/99         17            36                       43                         7                            40                             1.663 MB      2769. MB       88
#   split            (3, 1)             16777216/99         34            36                       43                         7                            40                             2.111 MB      2769. MB       88
#   fold             (3, 1)             16777216/99         11            43                       42                         8                            40                             2.111 MB      1024. MB       87
#   bdecomp          (3, 1)             16777216/99         33            23                       30                         3                            30                             2.497 MB      1152. MB       87
#   norm-hp-tensor   (3, 2)             16777216/99         43            23                       23                         3                            23                             2.511 MB      1501. MB       87
#   batch            (3, 1)             16777216/99         43            23                       45                         3                            42                             2.511 MB      1501. MB       87
#   split            (3, 1)             8388608/99          86            23                       45                         3                            42                             3.645 MB      1501. MB       87
#   fold             (3, 1)             8388608/99          11            32                       45                         4                            42                             3.645 MB      256.0 MB       86
#   norm             (3, 4)             8388608/99          19            32                       32                         4                            32                             4.036 MB      442.2 MB       86
#   batch            (3, 1)             8388608/99          19            32                       39                         4                            36                             4.036 MB      442.2 MB       86
#   split            (3, 1)             4194304/99          38            32                       39                         4                            36                             4.537 MB      442.2 MB       86
#   fold             (3, 1)             4194304/99          11            39                       39                         5                            36                             4.537 MB      160.0 MB       86
#   bdecomp          (3, 1)             4194304/99          33            21                       26                         2                            26                             4.924 MB      192.0 MB       86
#   norm-hp-tensor   (3, 2)             4194304/99          45            21                       21                         2                            21                             4.936 MB      261.8 MB       86
#   batch            (3, 1)             4194304/99          45            21                       44                         2                            40                             4.936 MB      261.8 MB       86
#   split            (3, 1)             2097152/99          90            21                       44                         2                            40                             6.123 MB      261.8 MB       86
#   fold             (3, 1)             2097152/99          11            30                       43                         3                            40                             6.123 MB      48.00 MB       86
#   norm             (3, 4)             2097152/99          20            30                       30                         3                            30                             6.545 MB      87.27 MB       86
#   batch            (3, 1)             2097152/99          20            30                       50                         3                            47                             6.545 MB      87.27 MB       86
#   split            (3, 1)             1048576/99          40            30                       50                         3                            47                             7.072 MB      87.27 MB       86
#   fold             (3, 1)             1048576/99          11            37                       50                         4                            47                             7.072 MB      32.00 MB       85
#   norm             (3, 4)             1048576/99          18            37                       37                         4                            37                             7.432 MB      52.36 MB       85
#   batch            (3, 1)             1048576/99          18            37                       38                         4                            35                             7.432 MB      52.36 MB       85
#   split            (3, 1)             524288/99           36            37                       38                         4                            35                             7.907 MB      52.36 MB       85
#   fold             (3, 1)             524288/99           11            44                       37                         5                            35                             7.907 MB      20.00 MB       85
#   bdecomp          (3, 1)             524288/99           33            20                       24                         2                            24                             8.294 MB      24.00 MB       85
#   norm-hp-tensor   (3, 2)             524288/99           44            20                       20                         2                            20                             8.305 MB      32.00 MB       85
#   batch            (3, 1)             524288/99           44            20                       37                         2                            33                             8.305 MB      32.00 MB       85
#   split            (3, 1)             262144/99           88            20                       37                         2                            33                             9.465 MB      32.00 MB       85
#   fold             (3, 1)             262144/99           11            28                       36                         3                            33                             9.465 MB      6.000 MB       85
#   bdecomp          (3, 1)             262144/99           33            19                       23                         1                            23                             9.852 MB      6.000 MB       85
#   norm-hp-tensor   (3, 2)             262144/99           46            19                       19                         1                            19                             9.862 MB      8.364 MB       85
#   batch            (3, 1)             262144/99           46            19                       41                         1                            12                             9.862 MB      8.364 MB       85
#   split            (3, 1)             131072/99           92            19                       41                         1                            12                             11.08 MB      8.364 MB       85
#   fold             (3, 1)             131072/99           11            27                       41                         2                            12                             11.08 MB      2.000 MB       85
#   finish           (3, 0)             131072/99           0             27                       27                         2                            2                              13.08 MB      0.0000 B       85

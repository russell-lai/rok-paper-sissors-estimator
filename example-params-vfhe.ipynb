# %%
from symbolic_variables import *
from gen_params import gen_ring_param, gen_sis_param, gen_sis_param_aggresive
from ring_params import *
from protocol import Protocol

# %%
ring_param = ring_param_2048_1024
ring_param["log_q"] = 90
sis_param = gen_sis_param(ring_param = ring_param, log_beta_sis = 66)
print(sis_param)
rep = 91
wit_rdim = 8192
beta_inf = 2^24
beta_2 = sqrt(wit_rdim * ring_param["phi"] * ring_param["fhat"]) * beta_inf
ell = 2
tdim = 2

protocol = Protocol(
    ring_param = ring_param,
    sis_param = sis_param,
    rep = rep, 
    wit_rdim = wit_rdim,  
    beta_2 = beta_2,
    beta_inf = beta_inf
)

loop_short = [("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
loop = [("bdecomp", {"ell":ell}), ("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
ops = loop + loop + loop + loop + loop + loop + [("finish", {})]

for op, params in ops:
    protocol.execute(op, **params)
protocol.extract()
protocol.print()
# Out:
# {'n': 2, 'log_beta_sis': 66}
# Global parameters:
#   conductor   ring degree   subtractive set size   log modulus   log sis norm      Rq size
#   v_f         v_phi         v_C                    log(v_q)      log(v_beta_sis)   v_ringelq
#   2048        1024          2                      90            66                8.000 KB
# Protocol history:
#   operation   #relations         witness dimension   bundle size   log witness norm can-2   log extration norm can-2   log witness norm coeff-inf   log extration norm coeff-inf   prover comm   witness size   soundness
#               (v_ntop, v_nbot)   v_wit_rdim          v_rep         log(v_beta_wit_2)        log(v_beta_ext_2)          log(2*v_beta_wit_inf)        log(2*v_beta_ext_inf)          v_pi          v_w            -log(v_snderr)
#   init        (2, 0)             8192                91            41                       45                         25                           45                             0.0000 B      2275. MB       +Infinity
#   bdecomp     (2, 0)             8192                182           32                       45                         12                           45                             1.422 MB      2184. MB       +Infinity
#   norm        (2, 3)             8192                186           32                       32                         12                           32                             5.844 MB      2232. MB       114
#   batch       (2, 1)             8192                186           32                       58                         12                           53                             5.844 MB      2232. MB       114
#   split       (2, 1)             4096                372           32                       58                         12                           53                             13.11 MB      2232. MB       114
#   fold        (2, 1)             4096                91            54                       57                         22                           53                             13.11 MB      1001. MB       83
#   bdecomp     (2, 1)             4096                182           31                       42                         11                           42                             15.24 MB      1001. MB       83
#   norm        (2, 4)             4096                186           31                       31                         11                           31                             19.70 MB      1023. MB       83
#   batch       (2, 1)             4096                186           31                       56                         11                           51                             19.70 MB      1023. MB       83
#   split       (2, 1)             2048                372           31                       56                         11                           51                             26.96 MB      1023. MB       83
#   fold        (2, 1)             2048                91            52                       55                         21                           51                             26.96 MB      477.8 MB       82
#   bdecomp     (2, 1)             2048                182           29                       40                         10                           40                             29.09 MB      455.0 MB       82
#   norm        (2, 4)             2048                186           29                       29                         10                           29                             33.55 MB      465.0 MB       82
#   batch       (2, 1)             2048                186           29                       55                         10                           50                             33.55 MB      465.0 MB       82
#   split       (2, 1)             1024                372           29                       55                         10                           50                             40.81 MB      465.0 MB       82
#   fold        (2, 1)             1024                91            51                       54                         20                           50                             40.81 MB      227.5 MB       81
#   bdecomp     (2, 1)             1024                182           29                       39                         10                           39                             42.95 MB      227.5 MB       81
#   norm        (2, 4)             1024                186           29                       29                         10                           29                             47.40 MB      232.5 MB       81
#   batch       (2, 1)             1024                186           29                       54                         10                           49                             47.40 MB      232.5 MB       81
#   split       (2, 1)             512                 372           29                       54                         10                           49                             54.66 MB      232.5 MB       81
#   fold        (2, 1)             512                 91            50                       53                         20                           49                             54.66 MB      113.8 MB       81
#   bdecomp     (2, 1)             512                 182           28                       38                         10                           38                             56.80 MB      113.8 MB       81
#   norm        (2, 4)             512                 186           28                       28                         10                           28                             61.25 MB      116.2 MB       81
#   batch       (2, 1)             512                 186           28                       53                         10                           48                             61.25 MB      116.2 MB       81
#   split       (2, 1)             256                 372           28                       53                         10                           48                             68.52 MB      116.2 MB       81
#   fold        (2, 1)             256                 91            50                       53                         20                           48                             68.52 MB      56.88 MB       81
#   bdecomp     (2, 1)             256                 182           27                       37                         10                           37                             70.65 MB      56.88 MB       81
#   norm        (2, 4)             256                 186           27                       27                         10                           27                             75.10 MB      58.12 MB       81
#   batch       (2, 1)             256                 186           27                       65                         10                           31                             75.10 MB      58.12 MB       81
#   split       (2, 1)             128                 372           27                       65                         10                           31                             82.37 MB      58.12 MB       81
#   fold        (2, 1)             128                 91            49                       64                         20                           31                             82.37 MB      28.44 MB       80
#   finish      (2, 0)             128                 0             49                       49                         20                           20                             110.8 MB      0.0000 B       80

# %%
log_q = 90

ring_param_31_30 = {
  'f': 1031,
  'fhat': 1031,
 'phi': 1030,
 'q': 2^log_q,
 'log_q': log_q,
 'Rq_size': log_q * 1030,
 'e': 2,
 'C': 1030,
 'gamma_2': 1030,
 'theta_2': 1030,
 'gamma_inf': 1030,
 'theta_inf': 1030,
 'ring_exp_inf': 1030}

ring_param = ring_param_31_30
sis_param = gen_sis_param(ring_param = ring_param, log_beta_sis = 66)
print(sis_param)
rep = 90
wit_rdim = 8192
beta_inf = 2^24
beta_2 = sqrt(wit_rdim * ring_param["phi"] * ring_param["fhat"]) * beta_inf
ell = 2
tdim = 2

protocol = Protocol(
    ring_param = ring_param,
    sis_param = sis_param,
    rep = rep, 
    wit_rdim = wit_rdim,  
    beta_2 = beta_2,
    beta_inf = beta_inf
)

loop_short = [("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
loop = [("bdecomp", {"ell":ell}), ("norm", {}), ("batch", {}), ("split", {"tdim":tdim}), ("fold", {"repout":rep})]
ops = loop + loop + loop + loop + loop + loop + [("finish", {})]

for op, params in ops:
    protocol.execute(op, **params)
protocol.extract()
protocol.print()
# Out:
# {'n': 2, 'log_beta_sis': 66}
# Global parameters:
#   conductor   ring degree   subtractive set size   log modulus   log sis norm      Rq size
#   v_f         v_phi         v_C                    log(v_q)      log(v_beta_sis)   v_ringelq
#   1031        1030          1030                   90            66                11.32 KB
# Protocol history:
#   operation   #relations         witness dimension   bundle size   log witness norm can-2   log extration norm can-2   log witness norm coeff-inf   log extration norm coeff-inf   prover comm   witness size   soundness
#               (v_ntop, v_nbot)   v_wit_rdim          v_rep         log(v_beta_wit_2)        log(v_beta_ext_2)          log(2*v_beta_wit_inf)        log(2*v_beta_ext_inf)          v_pi          v_w            -log(v_snderr)
#   init        (2, 0)             8192                90            41                       45                         25                           45                             0.0000 B      2263. MB       +Infinity
#   bdecomp     (2, 0)             8192                180           32                       45                         12                           45                             1.989 MB      2173. MB       +Infinity
#   norm        (2, 3)             8192                184           32                       32                         12                           32                             8.177 MB      2221. MB       166
#   batch       (2, 1)             8192                184           32                       58                         12                           53                             8.177 MB      2221. MB       166
#   split       (2, 1)             4096                368           32                       58                         12                           53                             18.34 MB      2221. MB       166
#   fold        (2, 1)             4096                90            54                       57                         22                           53                             18.34 MB      995.8 MB       166
#   bdecomp     (2, 1)             4096                180           31                       42                         11                           42                             21.33 MB      995.8 MB       166
#   norm        (2, 4)             4096                184           31                       31                         11                           31                             27.56 MB      1018. MB       166
#   batch       (2, 1)             4096                184           31                       56                         11                           51                             27.56 MB      1018. MB       166
#   split       (2, 1)             2048                368           31                       56                         11                           51                             37.73 MB      1018. MB       166
#   fold        (2, 1)             2048                90            52                       55                         21                           51                             37.73 MB      475.3 MB       166
#   bdecomp     (2, 1)             2048                180           29                       40                         10                           40                             40.71 MB      452.6 MB       166
#   norm        (2, 4)             2048                184           29                       29                         10                           29                             46.94 MB      462.7 MB       166
#   batch       (2, 1)             2048                184           29                       55                         10                           50                             46.94 MB      462.7 MB       166
#   split       (2, 1)             1024                368           29                       55                         10                           50                             57.11 MB      462.7 MB       166
#   fold        (2, 1)             1024                90            51                       54                         20                           50                             57.11 MB      226.3 MB       166
#   bdecomp     (2, 1)             1024                180           29                       39                         10                           39                             60.09 MB      226.3 MB       166
#   norm        (2, 4)             1024                184           29                       29                         10                           29                             66.33 MB      231.3 MB       166
#   batch       (2, 1)             1024                184           29                       54                         10                           49                             66.33 MB      231.3 MB       165
#   split       (2, 1)             512                 368           29                       54                         10                           49                             76.49 MB      231.3 MB       165
#   fold        (2, 1)             512                 90            50                       53                         20                           49                             76.49 MB      113.2 MB       165
#   bdecomp     (2, 1)             512                 180           28                       38                         10                           38                             79.48 MB      113.2 MB       165
#   norm        (2, 4)             512                 184           28                       28                         10                           28                             85.71 MB      115.7 MB       165
#   batch       (2, 1)             512                 184           28                       53                         10                           48                             85.71 MB      115.7 MB       165
#   split       (2, 1)             256                 368           28                       53                         10                           48                             95.88 MB      115.7 MB       165
#   fold        (2, 1)             256                 90            50                       53                         20                           48                             95.88 MB      56.58 MB       165
#   bdecomp     (2, 1)             256                 180           27                       37                         10                           37                             98.86 MB      56.58 MB       165
#   norm        (2, 4)             256                 184           27                       27                         10                           27                             105.1 MB      57.84 MB       165
#   batch       (2, 1)             256                 184           27                       65                         10                           31                             105.1 MB      57.84 MB       165
#   split       (2, 1)             128                 368           27                       65                         10                           31                             115.3 MB      57.84 MB       165
#   fold        (2, 1)             128                 90            49                       64                         20                           31                             115.3 MB      28.29 MB       165
#   finish      (2, 0)             128                 0             49                       49                         20                           20                             143.5 MB      0.0000 B       165

# %% [markdown]
# # Counting Elements in the Witness and Set 1
#
# To count the number of elements in the given sequences and sets, we analyze each expression individually.
#
# ### Expressions and Sets
# 1. **\( \hat{b}, \hat{r} \)**
#    - Number of elements: 2
#
# 2. **\( (t^{(j)}_i)_{i \in [n+1], j \in [2]} \)**
#    - \(i \in [n+1]\) means there are \(n+1\) values of \(i\).
#    - \(j \in [2]\) means there are 2 values of \(j\).
#    - Number of elements: \((n+1) \times 2 = 2n + 2\)
#
# 3. **\( (m^{(j)}_i, \hat{u}^{(j)}_i)_{i \in [n], j \in [2]} \)**
#    - For each \(i \in [n]\) and \(j \in [2]\), there are 2 elements (i.e., \(m^{(j)}_i\) and \(\hat{u}^{(j)}_i\)).
#    - Number of elements: \(n \times 2 \times 2 = 4n\)
#
# 4. **\( (\ddot{m}^{(j)}_{i, k})_{i \in [n+1], j \in [2], k \in [\ell_\bs]} \)**
#    - For each \(i \in [n+1]\), \(j \in [2]\), and \(k \in [\ell_\bs]\), there is 1 element.
#    - Number of elements: \((n+1) \times 2 \times \ell_\bs = 2(n+1) \times \ell_\bs\)
#
# 5. **\( (\hat{a}_i, e_i)_{i \in [n]} \)**
#    - For each \(i \in [n]\), there are 2 elements (\(\hat{a}_i\) and \(e_i\)).
#    - Number of elements: \(n \times 2 = 2n\)
#
# 6. **\( \tilde{b}, (\tilde{a}_h)_{h \in [N]} \)**
#    - There is 1 element \(\tilde{b}\).
#    - For each \(h \in [N]\), there is 1 element \(\tilde{a}_h\).
#    - Number of elements: \(1 + N = N + 1\)
#
# 7. **\( (\dot{a}_h)_{h \in [N]} \)**
#    - For each \(h \in [N]\), there is 1 element \(\dot{a}_h\).
#    - Number of elements: \(N\)
#
# 8. **\( (\ddot{a}_{h, k})_{h \in [N], k \in [\ell_\ks]} \)**
#    - For each \(h \in [N]\) and \(k \in [\ell_\ks]\), there is 1 element \(\ddot{a}_{h, k}\).
#    - Number of elements: \(N \times \ell_\ks\)
#
# ### Summing the Elements
#
# - Elements from expression 1: \(2\)
# - Elements from expression 2: \(2n + 2\)
# - Elements from expression 3: \(4n\)
# - Elements from expression 4: \((n+1) \times 2 \times \ell_\bs = 2(n+1) \times \ell_\bs\)
# - Elements from expression 5: \(2n\)
# - Elements from expression 6: \(N + 1\)
# - Elements from expression 7: \(N\)
# - Elements from expression 8: \(N \times \ell_\ks\)
#
# Adding these together:
# \[ 2 + 2n + 2 + 4n + 2(n+1) \times \ell_\bs + 2n + N + 1 + N + N \times \ell_\ks \]
#
# Combining like terms:
# \[ 2 + 2n + 2 + 4n + 2(n+1) \times \ell_\bs + 2n + N + 1 + N + N \times \ell_\ks= 8n + 2\ell_\bs + 4N +3 \]
#
# ### Plugging in Values
#
# Given:
# - \( q = 8 \)
# - \( n = 224 \)
# - \( N = 585 \)
# - \( \ell_\bs = 1024 \)
# - \( \ell_\ks = 28 \)
#
# Substitute the values:
# \[ 8(224) + 2(1024) + 4(585) + 3 \]
#
# Calculations:
# \[ 1792 + 2048 + 2340 + 3 = 6183 \]
#
# The total number of elements in the given sequences and sets is **6183**.
